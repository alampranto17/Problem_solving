# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('import all libary')
# Out:
# import all libary

# %%
# all csv import
courses=pd.read_csv('/content/courses.csv')
students=pd.read_csv('/content/students.csv')
reg_months=pd.read_csv('/content/reg-month1.csv')
reg_months_two=pd.read_csv('/content/reg-month2.csv')
matches=pd.read_csv('/content/matches.csv')
ipl=pd.read_csv('/content/deliveries.csv')

print("all the Csv file are imported".title())
# Out:
# All The Csv File Are Imported

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# 20          21          Seema Kota       15
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18
# 23          24        Radhika Suri       17
# 24          25     Shashank D’Alia        2

# %%
reg_months
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
reg_months_two
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
ipl
# Out:
#        match_id  inning                 batting_team  \
# 0             1     1.0          Sunrisers Hyderabad
# 1             1     1.0          Sunrisers Hyderabad
# 2             1     1.0          Sunrisers Hyderabad
# 3             1     1.0          Sunrisers Hyderabad
# 4             1     1.0          Sunrisers Hyderabad
# ...         ...     ...                          ...
# 40899       174     2.0  Royal Challengers Bangalore
# 40900       174     2.0  Royal Challengers Bangalore
# 40901       174     2.0  Royal Challengers Bangalore
# 40902       174     2.0  Royal Challengers Bangalore
# 40903       174     NaN                          NaN
#
#                       bowling_team  over  ball      batsman  non_striker  \
# 0      Royal Challengers Bangalore   1.0   1.0    DA Warner     S Dhawan
# 1      Royal Challengers Bangalore   1.0   2.0    DA Warner     S Dhawan
# 2      Royal Challengers Bangalore   1.0   3.0    DA Warner     S Dhawan
# 3      Royal Challengers Bangalore   1.0   4.0    DA Warner     S Dhawan
# 4      Royal Challengers Bangalore   1.0   5.0    DA Warner     S Dhawan
# ...                            ...   ...   ...          ...          ...
# 40899              Deccan Chargers  11.0   3.0     R Dravid  LRPL Taylor
# 40900              Deccan Chargers  11.0   4.0     R Dravid  LRPL Taylor
# 40901              Deccan Chargers  11.0   5.0  LRPL Taylor     R Dravid
# 40902              Deccan Chargers  11.0   6.0     R Dravid  LRPL Taylor
# 40903                          NaN   NaN   NaN          NaN          NaN
#
#           bowler  is_super_over  ...  bye_runs  legbye_runs  noball_runs  \
# 0       TS Mills            0.0  ...       0.0          0.0          0.0
# 1       TS Mills            0.0  ...       0.0          0.0          0.0
# 2       TS Mills            0.0  ...       0.0          0.0          0.0
# 3       TS Mills            0.0  ...       0.0          0.0          0.0
# 4       TS Mills            0.0  ...       0.0          0.0          0.0
# ...          ...            ...  ...       ...          ...          ...
# 40899  RG Sharma            0.0  ...       0.0          0.0          0.0
# 40900  RG Sharma            0.0  ...       0.0          0.0          0.0
# 40901  RG Sharma            0.0  ...       0.0          0.0          0.0
# 40902  RG Sharma            0.0  ...       0.0          0.0          0.0
# 40903        NaN            NaN  ...       NaN          NaN          NaN
#
#        penalty_runs  batsman_runs  extra_runs  total_runs  player_dismissed  \
# 0               0.0           0.0         0.0         0.0               NaN
# 1               0.0           0.0         0.0         0.0               NaN
# 2               0.0           4.0         0.0         4.0               NaN
# 3               0.0           0.0         0.0         0.0               NaN
# 4               0.0           0.0         2.0         2.0               NaN
# ...             ...           ...         ...         ...               ...
# 40899           0.0           2.0         0.0         2.0               NaN
# 40900           0.0           1.0         0.0         1.0               NaN
# 40901           0.0           1.0         0.0         1.0               NaN
# 40902           0.0           2.0         0.0         2.0               NaN
# 40903           NaN           NaN         NaN         NaN               NaN
#
#       dismissal_kind fielder
# 0                NaN     NaN
# 1                NaN     NaN
# 2                NaN     NaN
# 3                NaN     NaN
# 4                NaN     NaN
# ...              ...     ...
# 40899            NaN     NaN
# 40900            NaN     NaN
# 40901            NaN     NaN
# 40902            NaN     NaN
# 40903            NaN     NaN
#
# [40904 rows x 21 columns]

# %%
# concate
all_reg=pd.concat([reg_months,reg_months_two],ignore_index=True)
all_reg
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# 34          11          8
# 35          14          6
# 36          12          5
# 37          12          7
# 38          18          8
# 39           1         10
# 40           1          9
# 41           2          5
# 42           7          6
# 43          22          5
# 44          22          6
# 45          23          9
# 46          23          5
# 47          14          4
# 48          14          1
# 49          11         10
# 50          42          9
# 51          50          8
# 52          38          1

# %%
# multi_index

reg=pd.concat([reg_months,reg_months_two],keys=['Nov','Dec'])
reg

reg.loc['Nov']

reg.loc[('Dec',8)]
# Out:
# student_id    17
# course_id     10
# Name: (Dec, 8), dtype: int64

# %%
inner=pd.merge(left=all_reg,right=students,on='student_id',how='inner')
inner
# Out:
#     student_id  course_id                name  partner
# 0           23          1      Chhavi Lachman       18
# 1           15          5           Preet Sha       16
# 2           18          6     Fardeen Mahabir       13
# 3           23          4      Chhavi Lachman       18
# 4           16          9        Elias Dodiya       25
# 5           18          1     Fardeen Mahabir       13
# 6            1          1       Kailash Harjo       23
# 7            7          8        Tarun Thaker        9
# 8           22          3          Yash Sethi       21
# 9           15          1           Preet Sha       16
# 10          19          4        Qabeel Raman       12
# 11           1          6       Kailash Harjo       23
# 12           7         10        Tarun Thaker        9
# 13          11          7  David Mukhopadhyay       20
# 14          13          3      Munni Varghese       24
# 15          24          4        Radhika Suri       17
# 16          21          1          Seema Kota       15
# 17          16          5        Elias Dodiya       25
# 18          23          3      Chhavi Lachman       18
# 19          17          7        Yasmin Palan        7
# 20          23          6      Chhavi Lachman       18
# 21          25          1     Shashank D’Alia        2
# 22          19          2        Qabeel Raman       12
# 23          25         10     Shashank D’Alia        2
# 24           3          3      Parveen Bhalla        3
# 25           3          5      Parveen Bhalla        3
# 26          16          7        Elias Dodiya       25
# 27          12         10          Radha Dutt       19
# 28          12          1          Radha Dutt       19
# 29          14          9    Pranab Natarajan       22
# 30           7          7        Tarun Thaker        9
# 31           7          2        Tarun Thaker        9
# 32          16          3        Elias Dodiya       25
# 33          17         10        Yasmin Palan        7
# 34          11          8  David Mukhopadhyay       20
# 35          14          6    Pranab Natarajan       22
# 36          12          5          Radha Dutt       19
# 37          12          7          Radha Dutt       19
# 38          18          8     Fardeen Mahabir       13
# 39           1         10       Kailash Harjo       23
# 40           1          9       Kailash Harjo       23
# 41           2          5         Esha Butala        1
# 42           7          6        Tarun Thaker        9
# 43          22          5          Yash Sethi       21
# 44          22          6          Yash Sethi       21
# 45          23          9      Chhavi Lachman       18
# 46          23          5      Chhavi Lachman       18
# 47          14          4    Pranab Natarajan       22
# 48          14          1    Pranab Natarajan       22
# 49          11         10  David Mukhopadhyay       20

# %%
# left join
left=pd.merge(left=courses,right=inner,how='left',on='course_id')
left
# Out:
#     course_id       course_name  price  student_id                name  \
# 0           1            python   2499        23.0      Chhavi Lachman
# 1           1            python   2499        18.0     Fardeen Mahabir
# 2           1            python   2499         1.0       Kailash Harjo
# 3           1            python   2499        15.0           Preet Sha
# 4           1            python   2499        21.0          Seema Kota
# 5           1            python   2499        25.0     Shashank D’Alia
# 6           1            python   2499        12.0          Radha Dutt
# 7           1            python   2499        14.0    Pranab Natarajan
# 8           2               sql   3499        19.0        Qabeel Raman
# 9           2               sql   3499         7.0        Tarun Thaker
# 10          3     data analysis   4999        22.0          Yash Sethi
# 11          3     data analysis   4999        13.0      Munni Varghese
# 12          3     data analysis   4999        23.0      Chhavi Lachman
# 13          3     data analysis   4999         3.0      Parveen Bhalla
# 14          3     data analysis   4999        16.0        Elias Dodiya
# 15          4  machine learning   9999        23.0      Chhavi Lachman
# 16          4  machine learning   9999        19.0        Qabeel Raman
# 17          4  machine learning   9999        24.0        Radhika Suri
# 18          4  machine learning   9999        14.0    Pranab Natarajan
# 19          5           tableau   2499        15.0           Preet Sha
# 20          5           tableau   2499        16.0        Elias Dodiya
# 21          5           tableau   2499         3.0      Parveen Bhalla
# 22          5           tableau   2499        12.0          Radha Dutt
# 23          5           tableau   2499         2.0         Esha Butala
# 24          5           tableau   2499        22.0          Yash Sethi
# 25          5           tableau   2499        23.0      Chhavi Lachman
# 26          6          power bi   1899        18.0     Fardeen Mahabir
# 27          6          power bi   1899         1.0       Kailash Harjo
# 28          6          power bi   1899        23.0      Chhavi Lachman
# 29          6          power bi   1899        14.0    Pranab Natarajan
# 30          6          power bi   1899         7.0        Tarun Thaker
# 31          6          power bi   1899        22.0          Yash Sethi
# 32          7          ms sxcel   1599        11.0  David Mukhopadhyay
# 33          7          ms sxcel   1599        17.0        Yasmin Palan
# 34          7          ms sxcel   1599        16.0        Elias Dodiya
# 35          7          ms sxcel   1599         7.0        Tarun Thaker
# 36          7          ms sxcel   1599        12.0          Radha Dutt
# 37          8            pandas   1099         7.0        Tarun Thaker
# 38          8            pandas   1099        11.0  David Mukhopadhyay
# 39          8            pandas   1099        18.0     Fardeen Mahabir
# 40          9            plotly    699        16.0        Elias Dodiya
# 41          9            plotly    699        14.0    Pranab Natarajan
# 42          9            plotly    699         1.0       Kailash Harjo
# 43          9            plotly    699        23.0      Chhavi Lachman
# 44         10           pyspark   2499         7.0        Tarun Thaker
# 45         10           pyspark   2499        25.0     Shashank D’Alia
# 46         10           pyspark   2499        12.0          Radha Dutt
# 47         10           pyspark   2499        17.0        Yasmin Palan
# 48         10           pyspark   2499         1.0       Kailash Harjo
# 49         10           pyspark   2499        11.0  David Mukhopadhyay
# 50         11             Numpy    699         NaN                 NaN
# 51         12               C++   1299         NaN                 NaN
#
#     partner
# 0      18.0
# 1      13.0
# 2      23.0
# 3      16.0
# 4      15.0
# 5       2.0
# 6      19.0
# 7      22.0
# 8      12.0
# 9       9.0
# 10     21.0
# 11     24.0
# 12     18.0
# 13      3.0
# 14     25.0
# 15     18.0
# 16     12.0
# 17     17.0
# 18     22.0
# 19     16.0
# 20     25.0
# 21      3.0
# 22     19.0
# 23      1.0
# 24     21.0
# 25     18.0
# 26     13.0
# 27     23.0
# 28     18.0
# 29     22.0
# 30      9.0
# 31     21.0
# 32     20.0
# 33      7.0
# 34     25.0
# 35      9.0
# 36     19.0
# 37      9.0
# 38     20.0
# 39     13.0
# 40     25.0
# 41     22.0
# 42     23.0
# 43     18.0
# 44      9.0
# 45      2.0
# 46     19.0
# 47      7.0
# 48     23.0
# 49     20.0
# 50      NaN
# 51      NaN

# %%
# 1.find the total_number of revenue

reg=pd.merge(left=all_reg,right=courses,how='inner',on='course_id')
sum=0
for i in reg['price']:
  sum+=i
print(sum)
# Out:
# 154247

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
dta=pd.concat([reg_months,reg_months_two],keys=['Nov','Dec']).reset_index()
dta=dta.merge(courses,how='left',on='course_id')

dta=dta.drop('level_1',axis=1)
dta.groupby(['level_0']).agg({'price':'sum','student_id':'count','course_id':'count'})
# dta.groupby(['level_0','course_name']).agg({'price':'sum','student_id':'count','course_id':'count'})
# Out:
#          price  student_id  course_id
# level_0
# Dec      65072          28         28
# Nov      89175          25         25

# %%
# find who are enroll both nov and dec

# using numpy

common_student_id=np.intersect1d(reg_months['student_id'],reg_months_two['student_id'])
students[students['student_id'].isin(common_student_id)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
# kun kun course keo buy kore nai

courses[~courses['course_id'].isin(all_reg['course_id'])]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
# using numpy
notBY=np.setdiff1d(courses['course_id'],all_reg['course_id'])
courses[courses['course_id'].isin(notBY)]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
# which students do not enroll any couses ?

# numpy
studentNotReg=np.setdiff1d(students['student_id'],all_reg['student_id'])
students[students['student_id'].isin(studentNotReg)]
# Out:
#     student_id                name  partner
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 19          20       Hanuman Hegde       11

# %%
students[~students['student_id'].isin(all_reg['student_id'])]
# Out:
#     student_id                name  partner
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 19          20       Hanuman Hegde       11

# %%
# self join
students.merge(students,how='inner',left_on='partner',right_on='student_id')[['student_id_x','name_x','name_y']].rename(columns={'student_id_x':'student_id','name_x':'student_name','name_y':'partner_name'})
# Out:
#     student_id        student_name        partner_name
# 0            1       Kailash Harjo      Chhavi Lachman
# 1            2         Esha Butala       Kailash Harjo
# 2            3      Parveen Bhalla      Parveen Bhalla
# 3            4         Marlo Dugal    Pranab Natarajan
# 4            5         Kusum Bahri  Lakshmi Contractor
# 5            6  Lakshmi Contractor      Aayushman Sant
# 6            7        Tarun Thaker   Nitika Chatterjee
# 7            8      Radheshyam Dey         Kusum Bahri
# 8            9   Nitika Chatterjee         Marlo Dugal
# 9           10      Aayushman Sant      Radheshyam Dey
# 10          11  David Mukhopadhyay       Hanuman Hegde
# 11          12          Radha Dutt        Qabeel Raman
# 12          13      Munni Varghese        Radhika Suri
# 13          14    Pranab Natarajan          Yash Sethi
# 14          15           Preet Sha        Elias Dodiya
# 15          16        Elias Dodiya     Shashank D’Alia
# 16          17        Yasmin Palan        Tarun Thaker
# 17          18     Fardeen Mahabir      Munni Varghese
# 18          19        Qabeel Raman          Radha Dutt
# 19          20       Hanuman Hegde  David Mukhopadhyay
# 20          21          Seema Kota           Preet Sha
# 21          22          Yash Sethi          Seema Kota
# 22          23      Chhavi Lachman     Fardeen Mahabir
# 23          24        Radhika Suri        Yasmin Palan
# 24          25     Shashank D’Alia         Esha Butala

# %%
# top 3 studnet who enroll most

top_three=students.merge(all_reg,how='inner',on='student_id').groupby('student_id')['course_id'].count().sort_values(ascending=False)[:3]

students[students['student_id'].isin(top_three.index)].merge(top_three,how='inner',on='student_id')
# Out:
#    student_id              name  partner  course_id
# 0           7      Tarun Thaker        9          5
# 1          14  Pranab Natarajan       22          4
# 2          23    Chhavi Lachman       18          6

# %%
# top 3 student who spend more money

full_df=students.merge(all_reg,how='inner',on='student_id').merge(courses,how='inner',on='course_id')
full_df.groupby(['student_id','name']).agg({'price':'sum'}).sort_values(by='price',ascending=False)[:3]
# Out:
#                              price
# student_id name
# 23         Chhavi Lachman    22594
# 14         Pranab Natarajan  15096
# 19         Qabeel Raman      13498

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40904 entries, 0 to 40903
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          40904 non-null  int64
#  1   inning            40903 non-null  float64
#  2   batting_team      40903 non-null  object
#  3   bowling_team      40903 non-null  object
#  4   over              40903 non-null  float64
#  5   ball              40903 non-null  float64
#  6   batsman           40903 non-null  object
#  7   non_striker       40903 non-null  object
#  8   bowler            40903 non-null  object
#  9   is_super_over     40903 non-null  float64
#  10  wide_runs         40903 non-null  float64
#  11  bye_runs          40903 non-null  float64
#  12  legbye_runs       40903 non-null  float64
#  13  noball_runs       40903 non-null  float64
#  14  penalty_runs      40903 non-null  float64
#  15  batsman_runs      40903 non-null  float64
#  16  extra_runs        40903 non-null  float64
#  17  total_runs        40903 non-null  float64
#  18  player_dismissed  2093 non-null   object
#  19  dismissal_kind    2093 non-null   object
#  20  fielder           1511 non-null   object
# dtypes: float64(12), int64(1), object(8)
# memory usage: 6.6+ MB

# %%
# top 3 studiums heighest 6 retio

temp_df=ipl.merge(matches,how='inner',left_on='match_id',right_on='id')

six_df = temp_df[temp_df['batsman_runs'] == 6]

num_sixes = six_df.groupby('venue')['venue'].count()

# total_matches=matches['venue'].value_counts()

num_matches = matches['venue'].value_counts()

(num_sixes/num_matches).sort_values(ascending=False).head(10)
# Out:
# venue
# Holkar Cricket Stadium                     12.000000
# De Beers Diamond Oval                      11.333333
# SuperSport Park                            10.000000
# Newlands                                    9.000000
# Buffalo Park                                9.000000
# St George's Park                            8.857143
# Kingsmead                                   8.666667
# New Wanderers Stadium                       7.750000
# Saurashtra Cricket Association Stadium      7.300000
# Maharashtra Cricket Association Stadium     5.266667
# dtype: float64
