# %%
import pandas as pd
import numpy as np

print ("library load")
# Out:
# library load

# %%
# using list making data frame

student_data=[
    [100,80,10],
    [60,70,7],
    [120,100,14],
    [80,50,2]
]

columns=['Id','Marks','packages']

# print(student_data)

data=pd.DataFrame(student_data,columns=columns)

print(data)

print(type(data))

print(type(data.Id))
# Out:
#     Id  Marks  packages
# 0  100     80        10
# 1   60     70         7
# 2  120    100        14
# 3   80     50         2
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
# #dic use kore dataframe

student_dic={
    'iq':[100,90,120,80],
    'marks':[80,70,100,50],
    'package':[10,7,14,2]
}

print(pd.DataFrame(student_dic))
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
movies=pd.read_csv('/content/movies.csv')

movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...                                                 ...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
#                             title_y                 original_title  is_adult  \
# 0          Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                     Battalion 609                  Battalion 609         0
# 2     The Accidental Prime Minister  The Accidental Prime Minister         0
# 3                   Why Cheat India                Why Cheat India         0
# 4                   Evening Shadows                Evening Shadows         0
# ...                             ...                            ...       ...
# 1624          Tera Mera Saath Rahen          Tera Mera Saath Rahen         0
# 1625           Yeh Zindagi Ka Safar           Yeh Zindagi Ka Safar         0
# 1626                Sabse Bada Sukh                Sabse Bada Sukh         0
# 1627                          Daaka                          Daaka         0
# 1628                       Humsafar                       Humsafar         0
#
#       year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0                2019     138  Action|Drama|War          8.4       35112
# 1                2019     131               War          4.1          73
# 2                2019     112   Biography|Drama          6.1        5549
# 3                2019     121       Crime|Drama          6.0        1891
# 4                2018     102             Drama          7.3         280
# ...               ...     ...               ...          ...         ...
# 1624             2001     148             Drama          4.9         278
# 1625             2001     146             Drama          3.0         133
# 1626             2018      \N      Comedy|Drama          6.1          13
# 1627             2019     136            Action          7.4          38
# 1628             2011      35     Drama|Romance          9.0        2968
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 1     The story revolves around a cricket match betw...
# 2     Based on the memoir by Indian policy analyst S...
# 3     The movie focuses on existing malpractices in ...
# 4     While gay rights and marriage equality has bee...
# ...                                                 ...
# 1624  Raj Dixit lives with his younger brother  Rahu...
# 1625  Hindi pop-star  Sarina Devan  lives a wealthy ...
# 1626  Village born Lalloo re-locates to Bombay  and ...
# 1627  Shinda tries robbing a bank so he can be wealt...
# 1628  Sara and Ashar are childhood friends who share...
#
#                                                 summary tagline  \
# 0     Indian army special forces execute a covert op...     NaN
# 1     The story of Battalion 609 revolves around a c...     NaN
# 2     Explores Manmohan Singh's tenure as the Prime ...     NaN
# 3     The movie focuses on existing malpractices in ...     NaN
# 4     Under the 'Evening Shadows'  truth often plays...     NaN
# ...                                                 ...     ...
# 1624  A man is torn between his handicapped brother ...     NaN
# 1625  A singer finds out she was adopted when the ed...     NaN
# 1626  Village born Lalloo re-locates to Bombay  and ...     NaN
# 1627  Shinda tries robbing a bank so he can be wealt...     NaN
# 1628  Ashar and Khirad are forced to get married due...     NaN
#
#                                                  actors  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                          Gippy Grewal|Zareen Khan|
# 1628                                        Fawad Khan|
#
#             wins_nominations              release_date
# 0                     4 wins     11 January 2019 (USA)
# 1                        NaN   11 January 2019 (India)
# 2                        NaN     11 January 2019 (USA)
# 3                        NaN     18 January 2019 (USA)
# 4     17 wins & 1 nomination   11 January 2019 (India)
# ...                      ...                       ...
# 1624                     NaN   7 November 2001 (India)
# 1625                     NaN  16 November 2001 (India)
# 1626                     NaN                       NaN
# 1627                     NaN     1 November 2019 (USA)
# 1628                     NaN     TV Series (2011–2012)
#
# [1629 rows x 18 columns]

# %%
Ipl_matches=pd.read_csv('/content/ipl-matches.csv')
Ipl_matches
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %% [markdown]
# #attributes and method

# %%
#shape--> showing row and column

print("movies: ",movies.shape)

print("Ipl Matches : ",Ipl_matches.shape)
# Out:
# movies:  (1629, 18)
# Ipl Matches :  (950, 20)

# %%
# dtype showing all columns type
print("movies : \n",movies.dtypes,"\n")

print("Ipl Matches : \n",Ipl_matches.dtypes)
# Out:
# movies :
#  title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object
#
# Ipl Matches :
#  ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
movies.index
# it is used for using for loop fatch value

# for i in range(1,10):
#   print(movies.loc[i])
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
#column

movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
#value
Ipl_matches.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
#         'Aleem Dar', 'GA Pratapkumar'],
#        [335983, 'Chandigarh', '2008-04-19', ...,
#         "['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'Joginder Sharma', 'P Amarnath', 'MS Gony', 'M Muralitharan']",
#         'MR Benson', 'SL Shastri'],
#        [335982, 'Bangalore', '2008-04-18', ...,
#         "['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey', 'Mohammad Hafeez', 'LR Shukla', 'WP Saha', 'AB Agarkar', 'AB Dinda', 'M Kartik', 'I Sharma']",
#         'Asad Rauf', 'RE Koertzen']], dtype=object)

# %% [markdown]
# #Methods

# %%
#head and tail

movies.head(10)

Ipl_matches.tail(2)

#sample

Ipl_matches.sample(3)
# Out:
#           ID        City        Date   Season MatchNumber  \
# 753   501220  Chandigarh  2011-04-21     2011          23
# 95   1254098   Abu Dhabi  2021-09-26     2021          38
# 804   419136  Chandigarh  2010-04-02  2009/10          31
#
#                      Team1                        Team2  \
# 753        Kings XI Punjab             Rajasthan Royals
# 95   Kolkata Knight Riders          Chennai Super Kings
# 804        Kings XI Punjab  Royal Challengers Bangalore
#
#                                           Venue             TossWinner  \
# 753  Punjab Cricket Association Stadium, Mohali       Rajasthan Royals
# 95             Zayed Cricket Stadium, Abu Dhabi  Kolkata Knight Riders
# 804  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 753        field         N              Kings XI Punjab     Runs    48.0
# 95           bat         N          Chennai Super Kings  Wickets     2.0
# 804          bat         N  Royal Challengers Bangalore  Wickets     6.0
#
#     method Player_of_Match                                       Team1Players  \
# 753    NaN        SE Marsh  ['AC Gilchrist', 'PC Valthaty', 'SE Marsh', 'K...
# 95     NaN       RA Jadeja  ['Shubman Gill', 'VR Iyer', 'RA Tripathi', 'EJ...
# 804    NaN    KP Pietersen  ['SE Marsh', 'MS Bisla', 'KC Sangakkara', 'RS ...
#
#                                           Team2Players      Umpire1  \
# 753  ['SA Asnodkar', 'R Dravid', 'SR Watson', 'STR ...     S Asnani
# 95   ['RD Gaikwad', 'F du Plessis', 'MM Ali', 'AT R...  CB Gaffaney
# 804  ['MK Pandey', 'JH Kallis', 'KP Pietersen', 'V ...    BF Bowden
#
#           Umpire2
# 753    PR Reiffel
# 95   Tapan Sharma
# 804     M Erasmus

# %%
#info

Ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
#  16  wins_nominations  707 non-null    object
#  17  release_date      1522 non-null   object
# dtypes: float64(1), int64(3), object(14)
# memory usage: 229.2+ KB

# %%
#describe()

movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
Ipl_matches.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isNUll
movies.isnull()

# kun column e koto missing value ache ta jana jai
movies.isnull().sum()

# try with series
# movies.story[~movies.story.isnull()]

# try with dataframe
missing_values=movies.isnull().sum()

missing_values=missing_values[missing_values.values>0]

missing_values
# Out:
# poster_path          103
# story                 20
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
duplicate=movies.duplicated().sum()

if(duplicate==0):
  print("the is no duplicated value here!!!")
else:
  print("the is duplicated value here!!!")
# Out:
# the is no duplicated value here!!!

# %%
#rename()

movies.rename(columns={'title_x':'movie_name'})
# Out:
#                                 movie_name     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...                                                 ...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
#                             title_y                 original_title  is_adult  \
# 0          Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                     Battalion 609                  Battalion 609         0
# 2     The Accidental Prime Minister  The Accidental Prime Minister         0
# 3                   Why Cheat India                Why Cheat India         0
# 4                   Evening Shadows                Evening Shadows         0
# ...                             ...                            ...       ...
# 1624          Tera Mera Saath Rahen          Tera Mera Saath Rahen         0
# 1625           Yeh Zindagi Ka Safar           Yeh Zindagi Ka Safar         0
# 1626                Sabse Bada Sukh                Sabse Bada Sukh         0
# 1627                          Daaka                          Daaka         0
# 1628                       Humsafar                       Humsafar         0
#
#       year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0                2019     138  Action|Drama|War          8.4       35112
# 1                2019     131               War          4.1          73
# 2                2019     112   Biography|Drama          6.1        5549
# 3                2019     121       Crime|Drama          6.0        1891
# 4                2018     102             Drama          7.3         280
# ...               ...     ...               ...          ...         ...
# 1624             2001     148             Drama          4.9         278
# 1625             2001     146             Drama          3.0         133
# 1626             2018      \N      Comedy|Drama          6.1          13
# 1627             2019     136            Action          7.4          38
# 1628             2011      35     Drama|Romance          9.0        2968
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 1     The story revolves around a cricket match betw...
# 2     Based on the memoir by Indian policy analyst S...
# 3     The movie focuses on existing malpractices in ...
# 4     While gay rights and marriage equality has bee...
# ...                                                 ...
# 1624  Raj Dixit lives with his younger brother  Rahu...
# 1625  Hindi pop-star  Sarina Devan  lives a wealthy ...
# 1626  Village born Lalloo re-locates to Bombay  and ...
# 1627  Shinda tries robbing a bank so he can be wealt...
# 1628  Sara and Ashar are childhood friends who share...
#
#                                                 summary tagline  \
# 0     Indian army special forces execute a covert op...     NaN
# 1     The story of Battalion 609 revolves around a c...     NaN
# 2     Explores Manmohan Singh's tenure as the Prime ...     NaN
# 3     The movie focuses on existing malpractices in ...     NaN
# 4     Under the 'Evening Shadows'  truth often plays...     NaN
# ...                                                 ...     ...
# 1624  A man is torn between his handicapped brother ...     NaN
# 1625  A singer finds out she was adopted when the ed...     NaN
# 1626  Village born Lalloo re-locates to Bombay  and ...     NaN
# 1627  Shinda tries robbing a bank so he can be wealt...     NaN
# 1628  Ashar and Khirad are forced to get married due...     NaN
#
#                                                  actors  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                          Gippy Grewal|Zareen Khan|
# 1628                                        Fawad Khan|
#
#             wins_nominations              release_date
# 0                     4 wins     11 January 2019 (USA)
# 1                        NaN   11 January 2019 (India)
# 2                        NaN     11 January 2019 (USA)
# 3                        NaN     18 January 2019 (USA)
# 4     17 wins & 1 nomination   11 January 2019 (India)
# ...                      ...                       ...
# 1624                     NaN   7 November 2001 (India)
# 1625                     NaN  16 November 2001 (India)
# 1626                     NaN                       NaN
# 1627                     NaN     1 November 2019 (USA)
# 1628                     NaN     TV Series (2011–2012)
#
# [1629 rows x 18 columns]

# %% [markdown]
# #column and row

# %%
# single column

movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
# multiple columns
movies.columns
movies[['title_x','imdb_rating']]
# Out:
#                                    title_x  imdb_rating
# 0                 Uri: The Surgical Strike          8.4
# 1                            Battalion 609          4.1
# 2     The Accidental Prime Minister (film)          6.1
# 3                          Why Cheat India          6.0
# 4                          Evening Shadows          7.3
# ...                                    ...          ...
# 1624                 Tera Mera Saath Rahen          4.9
# 1625                  Yeh Zindagi Ka Safar          3.0
# 1626                       Sabse Bada Sukh          6.1
# 1627                                 Daaka          7.4
# 1628                              Humsafar          9.0
#
# [1629 rows x 2 columns]

# %%
# single row and multiple row
# fuction iloc and loc

movies.iloc[7]
# Out:
# title_x                                                    Bombairiya
# imdb_id                                                     tt4971258
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                    https://en.wikipedia.org/wiki/Bombairiya
# title_y                                                    Bombairiya
# original_title                                             Bombairiya
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           104
# genres                                             Comedy|Crime|Drama
# imdb_rating                                                       4.3
# imdb_votes                                                        295
# story               It follows the story of Meghna  who gets embro...
# summary             It follows the story of Meghna  who gets embro...
# tagline                         They didn't mean to change the world.
# actors              Radhika Apte|Akshay Oberoi|Siddhanth Kapoor|Ra...
# wins_nominations                                                  NaN
# release_date                                  18 January 2019 (India)
# Name: 7, dtype: object

# %%
movies.iloc[10:100:2]
# Out:
#                                  title_x     imdb_id  \
# 10                                Amavas   tt8396186
# 12                             Hum Chaar   tt9319812
# 14                            Sonchiriya   tt8108200
# 16                Mard Ko Dard Nahi Hota   tt8055888
# 18                     Photograph (film)   tt7778680
# 20             Mere Pyare Prime Minister   tt8207768
# 22                         Kesari (film)   tt6264938
# 24                   Junglee (2019 film)   tt7463730
# 26  Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 28                                Kalank   tt6988116
# 30                 Student of the Year 2   tt7255568
# 32                        De De Pyaar De   tt8647400
# 34                         Yeh Hai India   tt5525846
# 36                           Kabir Singh   tt8983202
# 38            One Day: Justice Delivered   tt8130558
# 40                       Super 30 (film)   tt7485048
# 42                           Batla House   tt8869978
# 44                  Judgementall Hai Kya   tt8108196
# 46                         Arjun Patiala   tt7881524
# 48                               Pranaam   tt7228072
# 50                        Mission Mangal   tt9248972
# 52                Dream Girl (2019 film)   tt9248940
# 54                The Zoya Factor (film)   tt8304386
# 56                           Prassthanam   tt8706884
# 58                     Ghost (2019 film)   tt9378950
# 60                    Yaaram (2019 film)  tt11007050
# 62                        Saand Ki Aankh   tt8108206
# 64                           Ujda Chaman  tt11046300
# 66                     Satellite Shankar   tt9179426
# 68                            Marjaavaan   tt9248934
# 70             Keep Safe Distance (film)   tt8876008
# 72                   Ramprasad Ki Tehrvi  tt10196464
# 74                           Dil Bechara   tt8110330
# 76                     Commando 3 (film)   tt8983168
# 78                             Dabangg 3   tt7059844
# 80                           Kaalakaandi   tt6102396
# 82                      My Birthday Song   tt4335954
# 84                             Mukkabaaz   tt7180544
# 86                  Love per Square Foot   tt7853242
# 88                             Padmaavat   tt5935704
# 90                  Jaane Kyun De Yaaron   tt7720254
# 92                Sonu Ke Titu Ki Sweety   tt7581902
# 94                          Dil Juunglee   tt6071752
# 96                      Raid (2018 film)   tt7363076
# 98                   Missing (2018 film)   tt7384848
#
#                                           poster_path  \
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
# 14  https://upload.wikimedia.org/wikipedia/en/thum...
# 16  https://upload.wikimedia.org/wikipedia/en/thum...
# 18  https://upload.wikimedia.org/wikipedia/en/7/71...
# 20  https://upload.wikimedia.org/wikipedia/en/thum...
# 22  https://upload.wikimedia.org/wikipedia/en/thum...
# 24  https://upload.wikimedia.org/wikipedia/en/e/e2...
# 26  https://upload.wikimedia.org/wikipedia/en/thum...
# 28  https://upload.wikimedia.org/wikipedia/en/thum...
# 30  https://upload.wikimedia.org/wikipedia/en/thum...
# 32  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 36  https://upload.wikimedia.org/wikipedia/en/thum...
# 38  https://upload.wikimedia.org/wikipedia/en/f/f7...
# 40  https://upload.wikimedia.org/wikipedia/en/thum...
# 42  https://upload.wikimedia.org/wikipedia/en/e/ed...
# 44  https://upload.wikimedia.org/wikipedia/en/c/c8...
# 46  https://upload.wikimedia.org/wikipedia/en/thum...
# 48  https://upload.wikimedia.org/wikipedia/en/thum...
# 50  https://upload.wikimedia.org/wikipedia/en/thum...
# 52  https://upload.wikimedia.org/wikipedia/en/thum...
# 54  https://upload.wikimedia.org/wikipedia/en/thum...
# 56  https://upload.wikimedia.org/wikipedia/en/thum...
# 58  https://upload.wikimedia.org/wikipedia/en/thum...
# 60  https://upload.wikimedia.org/wikipedia/en/thum...
# 62  https://upload.wikimedia.org/wikipedia/en/thum...
# 64  https://upload.wikimedia.org/wikipedia/en/thum...
# 66  https://upload.wikimedia.org/wikipedia/en/thum...
# 68  https://upload.wikimedia.org/wikipedia/en/thum...
# 70                                                NaN
# 72  https://upload.wikimedia.org/wikipedia/en/thum...
# 74                                                NaN
# 76  https://upload.wikimedia.org/wikipedia/en/thum...
# 78  https://upload.wikimedia.org/wikipedia/en/thum...
# 80  https://upload.wikimedia.org/wikipedia/en/thum...
# 82  https://upload.wikimedia.org/wikipedia/en/thum...
# 84  https://upload.wikimedia.org/wikipedia/en/thum...
# 86  https://upload.wikimedia.org/wikipedia/en/3/3d...
# 88  https://upload.wikimedia.org/wikipedia/en/thum...
# 90  https://upload.wikimedia.org/wikipedia/en/thum...
# 92  https://upload.wikimedia.org/wikipedia/en/thum...
# 94  https://upload.wikimedia.org/wikipedia/en/8/8d...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
# 98  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 10               https://en.wikipedia.org/wiki/Amavas
# 12            https://en.wikipedia.org/wiki/Hum_Chaar
# 14           https://en.wikipedia.org/wiki/Sonchiriya
# 16  https://en.wikipedia.org/wiki/Mard_Ko_Dard_Nah...
# 18    https://en.wikipedia.org/wiki/Photograph_(film)
# 20  https://en.wikipedia.org/wiki/Mere_Pyare_Prime...
# 22        https://en.wikipedia.org/wiki/Kesari_(film)
# 24  https://en.wikipedia.org/wiki/Junglee_(2019_film)
# 26  https://en.wikipedia.org/wiki/Albert_Pinto_Ko_...
# 28               https://en.wikipedia.org/wiki/Kalank
# 30  https://en.wikipedia.org/wiki/Student_of_the_Y...
# 32       https://en.wikipedia.org/wiki/De_De_Pyaar_De
# 34        https://en.wikipedia.org/wiki/Yeh_Hai_India
# 36          https://en.wikipedia.org/wiki/Kabir_Singh
# 38  https://en.wikipedia.org/wiki/One_Day:_Justice...
# 40      https://en.wikipedia.org/wiki/Super_30_(film)
# 42          https://en.wikipedia.org/wiki/Batla_House
# 44  https://en.wikipedia.org/wiki/Judgementall_Hai...
# 46        https://en.wikipedia.org/wiki/Arjun_Patiala
# 48              https://en.wikipedia.org/wiki/Pranaam
# 50       https://en.wikipedia.org/wiki/Mission_Mangal
# 52  https://en.wikipedia.org/wiki/Dream_Girl_(2019...
# 54  https://en.wikipedia.org/wiki/The_Zoya_Factor_...
# 56          https://en.wikipedia.org/wiki/Prassthanam
# 58    https://en.wikipedia.org/wiki/Ghost_(2019_film)
# 60   https://en.wikipedia.org/wiki/Yaaram_(2019_film)
# 62       https://en.wikipedia.org/wiki/Saand_Ki_Aankh
# 64          https://en.wikipedia.org/wiki/Ujda_Chaman
# 66    https://en.wikipedia.org/wiki/Satellite_Shankar
# 68           https://en.wikipedia.org/wiki/Marjaavaan
# 70  https://en.wikipedia.org/wiki/Keep_Safe_Distan...
# 72  https://en.wikipedia.org/wiki/Ramprasad_Ki_Tehrvi
# 74          https://en.wikipedia.org/wiki/Dil_Bechara
# 76    https://en.wikipedia.org/wiki/Commando_3_(film)
# 78            https://en.wikipedia.org/wiki/Dabangg_3
# 80          https://en.wikipedia.org/wiki/Kaalakaandi
# 82     https://en.wikipedia.org/wiki/My_Birthday_Song
# 84            https://en.wikipedia.org/wiki/Mukkabaaz
# 86  https://en.wikipedia.org/wiki/Love_Per_Square_...
# 88            https://en.wikipedia.org/wiki/Padmaavat
# 90  https://en.wikipedia.org/wiki/Jaane_Kyun_De_Ya...
# 92  https://en.wikipedia.org/wiki/Sonu_Ke_Titu_Ki_...
# 94         https://en.wikipedia.org/wiki/Dil_Juunglee
# 96     https://en.wikipedia.org/wiki/Raid_(2018_film)
# 98  https://en.wikipedia.org/wiki/Missing_(2018_film)
#
#                                  title_y  \
# 10                                Amavas
# 12                             Hum chaar
# 14                            Sonchiriya
# 16               Mard Ko Dard Nahin Hota
# 18                            Photograph
# 20             Mere Pyare Prime Minister
# 22                                Kesari
# 24                               Junglee
# 26  Albert Pinto Ko Gussa Kyun Aata Hai?
# 28                                Kalank
# 30                 Student of the Year 2
# 32                        De De Pyaar De
# 34                         Yeh Hai India
# 36                           Kabir Singh
# 38            One Day: Justice Delivered
# 40                              Super 30
# 42                           Batla House
# 44                  Judgementall Hai Kya
# 46                         Arjun Patiala
# 48                               Pranaam
# 50                        Mission Mangal
# 52                            Dream Girl
# 54                       The Zoya Factor
# 56                           Prassthanam
# 58                                 Ghost
# 60                               #Yaaram
# 62                        Saand Ki Aankh
# 64                           Ujda Chaman
# 66                     Satellite Shankar
# 68                            Marjaavaan
# 70                    Keep Safe Distance
# 72                   Ramprasad Ki Tehrvi
# 74                           Dil Bechara
# 76                            Commando 3
# 78                             Dabangg 3
# 80                           Kaalakaandi
# 82                      My Birthday Song
# 84                           The Brawler
# 86                  Love Per Square Foot
# 88                             Padmaavat
# 90                  Jaane kyun de yaaron
# 92                Sonu Ke Titu Ki Sweety
# 94                          Dil Juunglee
# 96                                  Raid
# 98                               Missing
#
#                           original_title  is_adult  year_of_release runtime  \
# 10                                Amavas         0             2019     134
# 12                             Hum chaar         0             2019     143
# 14                            Sonchiriya         0             2019     143
# 16               Mard Ko Dard Nahin Hota         0             2018     134
# 18                            Photograph         0             2019     110
# 20             Mere Pyare Prime Minister         0             2018     104
# 22                                Kesari         0             2019     150
# 24                               Junglee         0             2019     115
# 26  Albert Pinto Ko Gussa Kyun Aata Hai?         0             2019     100
# 28                                Kalank         0             2019     166
# 30                 Student of the Year 2         0             2019     146
# 32                        De De Pyaar De         0             2019     135
# 34                         Yeh Hai India         0             2017     128
# 36                           Kabir Singh         0             2019     173
# 38            One Day: Justice Delivered         0             2019     124
# 40                              Super 30         0             2019     154
# 42                           Batla House         0             2019     146
# 44                  Judgementall Hai Kya         0             2019     121
# 46                         Arjun Patiala         0             2019     107
# 48                               Pranaam         0             2019      \N
# 50                        Mission Mangal         0             2019     130
# 52                            Dream Girl         0             2019     132
# 54                       The Zoya Factor         0             2019     134
# 56                           Prassthanam         0             2019     141
# 58                                 Ghost         0             2019     130
# 60                               #Yaaram         0             2019      \N
# 62                        Saand Ki Aankh         0             2019     146
# 64                           Ujda Chaman         0             2019     120
# 66                     Satellite Shankar         0             2019     135
# 68                            Marjaavaan         0             2019     152
# 70                    Keep Safe Distance         0             2019     128
# 72                   Ramprasad Ki Tehrvi         0             2019     115
# 74                           Dil Bechara         0             2019     101
# 76                            Commando 3         0             2019     133
# 78                             Dabangg 3         0             2019     160
# 80                           Kaalakaandi         0             2018     112
# 82                      My Birthday Song         0             2018      95
# 84                             Mukkabaaz         0             2017     154
# 86                  Love Per Square Foot         0             2018     133
# 88                             Padmaavat         0             2018     164
# 90                  Jaane kyun de yaaron         0             2018     131
# 92                Sonu Ke Titu Ki Sweety         0             2018     138
# 94                          Dil Juunglee         0             2018     124
# 96                                  Raid         0             2018     122
# 98                               Missing         0             2018     120
#
#                     genres  imdb_rating  imdb_votes  \
# 10         Horror|Thriller          2.8         235
# 12                   Drama          5.6         183
# 14      Action|Crime|Drama          7.5        2322
# 16           Action|Comedy          7.4        3969
# 18           Drama|Romance          6.9        2391
# 20                   Drama          6.8         344
# 22    Action|Drama|History          7.4       10653
# 24        Action|Adventure          5.3        1064
# 26                   Drama          4.8          56
# 28           Drama|Romance          3.6        9106
# 30     Drama|Romance|Sport          2.5       12671
# 32          Comedy|Romance          6.6        5387
# 34  Action|Adventure|Drama          5.7         169
# 36           Drama|Romance          7.2       20535
# 38   Action|Crime|Thriller          6.8         590
# 40         Biography|Drama          8.2       13972
# 42   Action|Drama|Thriller          7.3        5556
# 44   Comedy|Drama|Thriller          6.0        3269
# 46           Action|Comedy          4.1         676
# 48      Action|Crime|Drama          7.0          43
# 50           Drama|History          6.5        7165
# 52          Comedy|Romance          7.5        4077
# 54    Comedy|Drama|Romance          4.1         683
# 56            Action|Drama          6.0         272
# 58         Horror|Thriller          8.7        1379
# 60          Comedy|Romance          5.7           7
# 62         Biography|Drama          8.9        1902
# 64                  Comedy          8.1        1440
# 66            Action|Drama          4.6          34
# 68          Action|Romance          3.6        3100
# 70         Action|Thriller          0.0           0
# 72            Comedy|Drama          7.6        3400
# 74           Drama|Romance          6.6      117000
# 76         Action|Thriller          5.7        2400
# 78                  Action          3.0       15000
# 80         Comedy|Thriller          6.2        1978
# 82                Thriller          5.5         215
# 84      Action|Drama|Sport          8.1        5434
# 86          Comedy|Romance          7.2        6248
# 88   Drama|History|Romance          7.0       24550
# 90                   Drama          4.4          25
# 92          Comedy|Romance          7.1       17378
# 94          Comedy|Romance          4.0         289
# 96      Action|Crime|Drama          7.4       13159
# 98  Drama|Mystery|Thriller          5.7        1642
#
#                                                 story  \
# 10  Far away from the bustle of the city  a young ...
# 12  The story of the film revolves around four col...
# 14  This is the story of a group of rebels in Cham...
# 16  It is a story of a young boy Surya who has a r...
# 18  Two lives intersect in Mumbai and go along tog...
# 20  A story about four children living in a Mumbai...
# 22  This period war-drama showcases the 1897 Battl...
# 24  Dipankar Nair runs a Elephant sanctuary but th...
# 26  Albert leaves his house one morning without te...
# 28  Set in 1945  in Pre-Independent India  the eli...
# 30  A student must face off against bullies and ov...
# 32  a 50 year old Aashish living London away from ...
# 34  Yeh Hai India  follows the story of a 25 years...
# 36  This Sandeep Vanga directorial is a remake of ...
# 38  A Crime Branch Special Officer Investigates th...
# 40  Anand Kumar  a Mathematics genius from a modes...
# 42  This action thriller is based on the real-life...
# 44  Following the story of two quirky individuals ...
# 46  Arjun Patiala(Diljit Dosanjh)has recently been...
# 48  A peon's son who is an aspiring IAS officer is...
# 50  Based on true events of the Indian Space Resea...
# 52  Rom-com Movie  directed by Raaj Shaandilyaa  s...
# 54  Based Anuja Chauhan's novel  Zoya Factor is a ...
# 56  A rural politician marries a widow with kids a...
# 58  The story of the film follows Karan Khanna  a ...
# 60  All set for an arranged marriage  Rohit Bajaj ...
# 62  Both over the age of 60  Chandro Tomar and Pra...
# 64  Ujda Chaman is about a 30 -year-old bachelor C...
# 66  The extraordinary journey of a soldier that br...
# 68  Marjaavaan is an upcoming Indian action romanc...
# 70  Keep Safe Distance is an upcoming Indian thril...
# 72                                                NaN
# 74            A love story about two cancer patients.
# 76  A mysterious man is on an impending mission to...
# 78      Third installment of the Dabanng film series.
# 80  Unfolding through a course of a night in Mumba...
# 82  After a wild night of impulse and passion  adv...
# 84  A boxer (Shravan) belonging to upper cast  tra...
# 86  Love Per Sq Ft  is a feature film which deals ...
# 88  This fictional story is set in 13th century me...
# 90  Raghu and Abhishek are two young rap singers  ...
# 92  We have always been told that "Marriage" is a ...
# 94  The movie is a romantic comedy that displays t...
# 96  Set in the 80s in Uttar Pradesh  India  Raid i...
# 98  Sushant Dubey checks in at a beach resort of M...
#
#                                               summary  \
# 10  The lives of a couple turn into a nightmare  a...
# 12  The story of the film revolves around four col...
# 14  Set in the Chambal valley  the film follows th...
# 16  It is a story of a young boy Surya who has a r...
# 18  A struggling street photographer in Mumbai  pr...
# 20  A story about four children living in a Mumbai...
# 22  Based on an incredible true story of the Battl...
# 24  The story revolves around a vet  who on his ho...
# 26  Albert Pinto goes missing one day and his girl...
# 28  The lives of six enigmatic characters become e...
# 30  A student must face off against bullies and ov...
# 32  A 50-year-old single father faces disapproval ...
# 34  Yeh Hai India  follows the story of a 25 years...
# 36  Kabir Singh is a remake of a Telugu movie Arju...
# 38  A Crime Branch Special Officer Investigates th...
# 40  Based on life of Patna-based mathematician Ana...
# 42  After a deadly encounter  a police officer wor...
# 44  Following the story of two quirky individuals ...
# 46  This spoof comedy narrates the story of a cop ...
# 48  A peon's son who is an aspiring IAS officer is...
# 50  Based on true events of the Indian Space Resea...
# 52  Rom-com Movie  directed by Raaj Shaandilyaa  s...
# 54  Based Anuja Chauhan's novel  Zoya Factor is a ...
# 56  A rural politician marries a widow with kids a...
# 58  The story of the film follows Karan Khanna  a ...
# 60  All set for an arranged marriage  Rohit Bajaj ...
# 62  Both over the age of 60  Chandro Tomar and Pra...
# 64  Ujda Chaman is about a 30 -year-old bachelor C...
# 66  The extraordinary journey of a soldier that br...
# 68  Marjaavaan is an upcoming Indian action romanc...
# 70  Keep Safe Distance is an upcoming Indian thril...
# 72                                       Add a Plot »
# 74            A love story about two cancer patients.
# 76  Commando 3 is a Hindi movie starring Vidyut Ja...
# 78      Third installment of the Dabanng film series.
# 80  Unfolding through a course of a night in Mumba...
# 82  After a wild night of impulse and passion  adv...
# 84  A boxer struggles to make his mark in the boxi...
# 86  Individually  Sanjay and Karina don't earn eno...
# 88  Set in medieval Rajasthan  Queen Padmavati is ...
# 90  Two boys with the dreams to change their ordin...
# 92  Titu is going to marry a perfect woman named S...
# 94  The movie is a romantic comedy that displays t...
# 96  A fearless income tax officer raids the mansio...
# 98  Sushant Dubey checks in at a beach resort of M...
#
#                                               tagline  \
# 10                                                NaN
# 12                                                NaN
# 14                                                NaN
# 16                                                NaN
# 18                                                NaN
# 20                           Meri Ek Arzi Sun Lo Zara
# 22                                                NaN
# 24                                                NaN
# 26                                                NaN
# 28                                                NaN
# 30                                                NaN
# 32                                                NaN
# 34                            A Film for Every Indian
# 36                                                NaN
# 38                                                NaN
# 40  Inspired by the Life of Anand Kumar & His Stud...
# 42  The Story of India's Most Decorated / Controve...
# 44                                                NaN
# 46                                                NaN
# 48                                                NaN
# 50   This Independence Day...The Sky is Not the Limit
# 52                                                NaN
# 54                                                NaN
# 56                                                NaN
# 58                                                NaN
# 60                                                NaN
# 62                                                NaN
# 64                                                NaN
# 66            Life is a journey with one perfect end.
# 68                                                NaN
# 70                                                NaN
# 72                      The Funeral Story of the Year
# 74                                                NaN
# 76                                                NaN
# 78                                                NaN
# 80                                                NaN
# 82                                                NaN
# 84                                                NaN
# 86                                                NaN
# 88                                                NaN
# 90                                                NaN
# 92                                                NaN
# 94                                                NaN
# 96                Heroes don't always come in uniform
# 98                                                NaN
#
#                                                actors  \
# 10  Ali Asgar|Vivan Bhatena|Nargis Fakhri|Sachiin ...
# 12  Prit Kamani|Simran Sharma|Anshuman Malhotra|Tu...
# 14  Sushant Singh Rajput|Bhumi Pednekar|Manoj Bajp...
# 16  Abhimanyu Dasani|Radhika Madan|Prateek Parmar|...
# 18  Nawazuddin Siddiqui|Sanya Malhotra|Sachin Khed...
# 20  Rasika Agashe|Sonia Albizuri|Syna Anand|Adarsh...
# 22  Akshay Kumar|Parineeti Chopra|Suvinder Vicky|V...
# 24                      Vidyut Jammwal|Lars Kjeldsen|
# 26                            Manav Kaul|Nandita Das|
# 28  Varun Dhawan|Alia Bhatt|Aditya Roy Kapoor|Madh...
# 30  Tiger Shroff|Ananya Panday|Tara Sutaria|Aditya...
# 32  Ajay Devgn|Tabu|Rakul Preet Singh|Jimmy Sheirg...
# 34   Gavie Chahal|Mohan Agashe|Mohan Joshi|Lom Harsh|
# 36  Shahid Kapoor|Kiara Advani|Soham Majumdar|Arja...
# 38  Anupam Kher|Kumud Mishra|Esha Gupta|Zakir Huss...
# 40  Hrithik Roshan|Mrunal Thakur|Nandish Singh|Vir...
# 42  John Abraham|Nora Fatehi|Mrunal Thakur|Rajesh ...
# 44  Kangana Ranaut|Rajkummar Rao|Amyra Dastur|Amri...
# 46  Diljit Dosanjh|Kriti Sanon|Varun Sharma|Ronit ...
# 48  Rajeev Khandelwal|Atul Kulkarni|Abhimanyu Sing...
# 50  Akshay Kumar|Vidya Balan|Nithya Menon|Taapsee ...
# 52  Ayushmann Khurrana|Nushrat Bharucha|Annu Kapoo...
# 54        Sonam Kapoor|Dulquer Salmaan|Sanjay Kapoor|
# 56  Sanjay Dutt|Jackie Shroff|Ali Fazal|Manisha Ko...
# 58  Sanaya Irani|Shivam Bhaargava|Vikram Bhatt|Ame...
# 60  Siddhanth Kapoor|Prateik|Anita Raj|Ishita Raj|...
# 62  Taapsee Pannu|Bhumi Pednekar|Prakash Jha|Viine...
# 64  Sunny Singh Nijjar|Maanvi Gagroo|Saurabh Shukl...
# 66                          Suraj Pancholi|Anil Reji|
# 68  Riteish Deshmukh|Sidharth Malhotra|Tara Sutari...
# 70  Shahbaaz Khan|Adi Irani|Vikas Anand|Kiran Kuma...
# 72  Naseeruddin Shah|Vikrant Massey|Konkona Sen Sh...
# 74    Sushant Singh Rajput|Sanjana Sanghi|Sahil Vaid|
# 76  Vidyut Jammwal|Adah Sharma|Angira Dhar|Sumeet ...
# 78  Salman Khan|Sonakshi Sinha|Sudeep|Mahesh Manjr...
# 80                                     Saif Ali Khan|
# 82  Nora Fatehi|Elena Kazan|Suparna Krishna|Pitoba...
# 84  Viineet Kumar|Jimmy Sheirgill|Zoya Hussain|Rav...
# 86  Vicky Kaushal|Angira Dhar|Alankrita Sahai|Ragh...
# 88  Deepika Padukone|Ranveer Singh|Shahid Kapoor|A...
# 90  Akshay Anand|Kabir Bedi|Hitesh Bhardwaj|Abhay ...
# 92  Kartik Aaryan|Nushrat Bharucha|Sunny Singh Nij...
# 94  Taapsee Pannu|Saqib Saleem|Nidhi Singh|Srishti...
# 96  Ajay Devgn|Saurabh Shukla|Ileana D'Cruz|Amit S...
# 98  Manoj Bajpayee|Tabu|Annu Kapoor|Rajesh Jais|Na...
#
#             wins_nominations              release_date Country  \
# 10                       NaN   8 February 2019 (India)   India
# 12                       NaN  15 February 2019 (India)   India
# 14                       NaN      1 March 2019 (India)   India
# 16    2 wins & 2 nominations       22 March 2019 (USA)   India
# 18                       NaN         17 May 2019 (USA)   India
# 20                       NaN     15 March 2019 (India)   India
# 22                       NaN       21 March 2019 (USA)   India
# 24                       NaN       29 March 2019 (USA)   India
# 26                       NaN     12 April 2019 (India)   India
# 28                       NaN       17 April 2019 (USA)   India
# 30                       NaN         10 May 2019 (USA)   India
# 32                       NaN         17 May 2019 (USA)   India
# 34     2 wins & 1 nomination       24 May 2019 (India)   India
# 36                       NaN        20 June 2019 (USA)   India
# 38                       NaN       5 July 2019 (India)   India
# 40                       NaN        12 July 2019 (USA)   India
# 42                       NaN      15 August 2019 (USA)   India
# 44                       NaN        26 July 2019 (USA)   India
# 46                       NaN        26 July 2019 (USA)   India
# 48                       NaN                       NaN   India
# 50                       NaN      15 August 2019 (USA)   India
# 52                       NaN   13 September 2019 (USA)   India
# 54                       NaN   20 September 2019 (USA)   India
# 56                       NaN   20 September 2019 (USA)   India
# 58                       NaN   18 October 2019 (India)   India
# 60                       NaN                       NaN   India
# 62              1 nomination     25 October 2019 (USA)   India
# 64                       NaN     1 November 2019 (USA)   India
# 66                       NaN   8 November 2019 (India)   India
# 68                       NaN    15 November 2019 (USA)   India
# 70                       NaN                       NaN   India
# 72                       NaN                       NaN   India
# 74                       NaN                       NaN   India
# 76                       NaN                       NaN   India
# 78                       NaN                       NaN   India
# 80                       NaN   12 January 2018 (India)   India
# 82                       NaN   19 January 2018 (India)   India
# 84    3 wins & 6 nominations     12 January 2018 (USA)   India
# 86                       NaN  14 February 2018 (India)   India
# 88  30 wins & 32 nominations   25 January 2018 (India)   India
# 90                       NaN  16 February 2018 (India)   India
# 92    4 wins & 9 nominations    23 February 2018 (USA)   India
# 94                       NaN      9 March 2018 (India)   India
# 96    2 wins & 3 nominations     16 March 2018 (India)   India
# 98                       NaN      6 April 2018 (India)   India
#
#             LeadingActor
# 10             Ali Asgar
# 12           Prit Kamani
# 14  Sushant Singh Rajput
# 16      Abhimanyu Dasani
# 18   Nawazuddin Siddiqui
# 20         Rasika Agashe
# 22          Akshay Kumar
# 24        Vidyut Jammwal
# 26            Manav Kaul
# 28          Varun Dhawan
# 30          Tiger Shroff
# 32            Ajay Devgn
# 34          Gavie Chahal
# 36         Shahid Kapoor
# 38           Anupam Kher
# 40        Hrithik Roshan
# 42          John Abraham
# 44        Kangana Ranaut
# 46        Diljit Dosanjh
# 48     Rajeev Khandelwal
# 50          Akshay Kumar
# 52    Ayushmann Khurrana
# 54          Sonam Kapoor
# 56           Sanjay Dutt
# 58          Sanaya Irani
# 60      Siddhanth Kapoor
# 62         Taapsee Pannu
# 64    Sunny Singh Nijjar
# 66        Suraj Pancholi
# 68      Riteish Deshmukh
# 70         Shahbaaz Khan
# 72      Naseeruddin Shah
# 74  Sushant Singh Rajput
# 76        Vidyut Jammwal
# 78           Salman Khan
# 80         Saif Ali Khan
# 82           Nora Fatehi
# 84         Viineet Kumar
# 86         Vicky Kaushal
# 88      Deepika Padukone
# 90          Akshay Anand
# 92         Kartik Aaryan
# 94         Taapsee Pannu
# 96            Ajay Devgn
# 98        Manoj Bajpayee

# %%
# fancy indexing
movies.iloc[[10,100,200,260]]
# Out:
#                          title_x    imdb_id  \
# 10                        Amavas  tt8396186
# 100          October (2018 film)  tt7700730
# 200  Tubelight (2017 Hindi film)  tt5882970
# 260                   Mastizaade  tt3726012
#
#                                            poster_path  \
# 10   https://upload.wikimedia.org/wikipedia/en/thum...
# 100  https://upload.wikimedia.org/wikipedia/en/thum...
# 200  https://upload.wikimedia.org/wikipedia/en/thum...
# 260  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link     title_y  \
# 10                https://en.wikipedia.org/wiki/Amavas      Amavas
# 100  https://en.wikipedia.org/wiki/October_(2018_film)     October
# 200  https://en.wikipedia.org/wiki/Tubelight_(2017_...   Tubelight
# 260           https://en.wikipedia.org/wiki/Mastizaade  Mastizaade
#
#     original_title  is_adult  year_of_release runtime           genres  \
# 10          Amavas         0             2019     134  Horror|Thriller
# 100        October         0             2018     115    Drama|Romance
# 200      Tubelight         0             2017     136        Drama|War
# 260     Mastizaade         0             2016     119           Comedy
#
#      imdb_rating  imdb_votes  \
# 10           2.8         235
# 100          7.5       11125
# 200          4.0       12911
# 260          2.3        2343
#
#                                                  story  \
# 10   Far away from the bustle of the city  a young ...
# 100  Dan (Varun Dhawan) is living the life of any c...
# 200  In a small picturesque town in North India  La...
# 260  Two womanizing bachelors fall in love with twi...
#
#                                                summary  \
# 10   The lives of a couple turn into a nightmare  a...
# 100  A group of interns are going through the usual...
# 200  A story of two brothers set during the Sino-In...
# 260  Two womanizing bachelors fall in love with twi...
#
#                                                tagline  \
# 10                                                 NaN
# 100  This is not a love story. This is a story abou...
# 200         Kya Tumhe Yakeen Hai? (Do You Have Faith?)
# 260                                                NaN
#
#                                                 actors  \
# 10   Ali Asgar|Vivan Bhatena|Nargis Fakhri|Sachiin ...
# 100  Varun Dhawan|Banita Sandhu|Gitanjali Rao|Sahil...
# 200  Salman Khan|Sohail Khan|Om Puri|Mohammed Zeesh...
# 260  Tusshar Kapoor|Vir Das|Sunny Leone|Asrani|Shaa...
#
#            wins_nominations             release_date
# 10                      NaN  8 February 2019 (India)
# 100  3 wins & 9 nominations      13 April 2018 (USA)
# 200   1 win & 3 nominations       23 June 2017 (USA)
# 260                     NaN    29 January 2016 (USA)

# %%
# filtering both row and columns

movies.iloc[10:100:2,0:4:2] #index position

movies.loc[0:10,['genres','imdb_rating']]#levels position with work
# Out:
#                     genres  imdb_rating
# 0         Action|Drama|War          8.4
# 1                      War          4.1
# 2          Biography|Drama          6.1
# 3              Crime|Drama          6.0
# 4                    Drama          7.3
# 5                    Drama          7.2
# 6             Comedy|Drama          4.2
# 7       Comedy|Crime|Drama          4.3
# 8   Action|Biography|Drama          6.5
# 9          Biography|Drama          5.1
# 10         Horror|Thriller          2.8

# %%
# find the final matchwinner and which team win and year

Ipl_matches.head(5)

all_final=Ipl_matches[Ipl_matches.MatchNumber=='Final']

print(all_final.shape[0])

print(all_final.columns)
result=all_final.sort_values(by='Season')

result=result.value_counts('WinningTeam')

result.plot(
    x='WinningTeam',
    y='Margin',
    kind='bar',           # Line plot also possible
    figsize=(10,6),
    title='IPL Final Winners by Season',
    legend=False,
    color='orange',
    xlabel="Winning Team",
    ylabel="Number of Trophy"
)
# Out:
# 15
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')
# <Axes: title={'center': 'IPL Final Winners by Season'}, xlabel='Winning Team', ylabel='Number of Trophy'>

# %%
# how many overfinish in super over

ipl_superOver=Ipl_matches[Ipl_matches.SuperOver=='Y']

print(ipl_superOver.shape[0])
# Out:
# 14

# %%
# how many match win in csk at kolkata

csk_match=Ipl_matches[(Ipl_matches.City=='Kolkata') & (Ipl_matches.WinningTeam=='Chennai Super Kings')]

print(csk_match.shape[0])
# Out:
# 5

# %%
# how many teams win and same team toss win
total_tosswinning=Ipl_matches[Ipl_matches.TossWinner==Ipl_matches.WinningTeam].shape[0]

print(total_tosswinning/Ipl_matches.shape[0]*100)
# Out:
# 51.473684210526315

# %%
# movie rating higher and equal then 8 and number of vote>1000

print(movies[(movies.imdb_rating>=8) & (movies.imdb_votes>1000)].shape[0]/movies.shape[0]*100)
# Out:
# 4.358502148557397

# %%
# kun kun movie action ase and rating 7.5 er beshi

def find_action(genres):
  return 'Action' in genres

# movies[movies.genres.str.split('|').apply(find_action) & (movies.imdb_rating>7.5)].shape

movies[movies.genres.str.contains('Action') & (movies.imdb_rating>7.5)].shape

Ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB

# %%
# create a function who win total number of matches

def WinnngMatches(team1,team2):
  return Ipl_matches[((Ipl_matches['Team1']==team1) & (Ipl_matches['Team2']==team2)) & ((Ipl_matches['WinningTeam']==team1) | (Ipl_matches['WinningTeam']==team2))]


WinnngMatches("Rajasthan Royals","Royal Challengers Bangalore")[['Team1','Team2','WinningTeam','WonBy']]
# Out:
#                 Team1                        Team2  \
# 35   Rajasthan Royals  Royal Challengers Bangalore
# 61   Rajasthan Royals  Royal Challengers Bangalore
# 91   Rajasthan Royals  Royal Challengers Bangalore
# 118  Rajasthan Royals  Royal Challengers Bangalore
# 160  Rajasthan Royals  Royal Challengers Bangalore
# 178  Rajasthan Royals  Royal Challengers Bangalore
# 261  Rajasthan Royals  Royal Challengers Bangalore
# 303  Rajasthan Royals  Royal Challengers Bangalore
# 470  Rajasthan Royals  Royal Challengers Bangalore
# 538  Rajasthan Royals  Royal Challengers Bangalore
# 588  Rajasthan Royals  Royal Challengers Bangalore
# 672  Rajasthan Royals  Royal Challengers Bangalore
# 721  Rajasthan Royals  Royal Challengers Bangalore
# 786  Rajasthan Royals  Royal Challengers Bangalore
# 911  Rajasthan Royals  Royal Challengers Bangalore
#
#                      WinningTeam    WonBy
# 35              Rajasthan Royals     Runs
# 61   Royal Challengers Bangalore  Wickets
# 91   Royal Challengers Bangalore  Wickets
# 118  Royal Challengers Bangalore  Wickets
# 160  Royal Challengers Bangalore  Wickets
# 178  Royal Challengers Bangalore  Wickets
# 261             Rajasthan Royals     Runs
# 303             Rajasthan Royals     Runs
# 470  Royal Challengers Bangalore  Wickets
# 538             Rajasthan Royals  Wickets
# 588             Rajasthan Royals  Wickets
# 672  Royal Challengers Bangalore     Runs
# 721  Royal Challengers Bangalore  Wickets
# 786  Royal Challengers Bangalore  Wickets
# 911             Rajasthan Royals     Runs

# %%
# Adding new columns
movies['Country']='India'

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
#  16  wins_nominations  707 non-null    object
#  17  release_date      1522 non-null   object
#  18  Country           1629 non-null   object
# dtypes: float64(1), int64(3), object(15)
# memory usage: 241.9+ KB

# %%
# finding missing value and drop them and dataset a column who is leading actor

missing_values=movies.isnull().sum()

missing_values=missing_values[missing_values.values>0]

print("Actor missing value : ",missing_values.actors)


clearmovies= movies.dropna(subset=['actors'])

movies["LeadingActor"]=clearmovies.actors.str.split('|').apply(lambda x:x[0])

movies.loc[:,['actors','LeadingActor']]
# Out:
# Actor missing value :  5
#                                                  actors      LeadingActor
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...     Vicky Kaushal
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...       Vicky Ahuja
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...       Anupam Kher
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...     Emraan Hashmi
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...  Mona Ambegaonkar
# ...                                                 ...               ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...        Ajay Devgn
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...     Ameesha Patel
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...       Vijay Arora
# 1627                          Gippy Grewal|Zareen Khan|      Gippy Grewal
# 1628                                        Fawad Khan|        Fawad Khan
#
# [1629 rows x 2 columns]

# %%
# Astype given column er datatype change kore

Ipl_matches.info()

Ipl_matches['ID']=Ipl_matches.ID.astype(np.int32)


Ipl_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 148.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
#  16  Team1Players     950 non-null    object
#  17  Team2Players     950 non-null    object
#  18  Umpire1          950 non-null    object
#  19  Umpire2          950 non-null    object
# dtypes: float64(1), int32(1), object(18)
# memory usage: 144.9+ KB

# %% [markdown]
# #Important function using in dataframe

# %%
#value_count(series and dataframe but in data frame it's calculate value of rows and not counts value of row duplicate)
#Ipl find man of match player but in only qualifier round just

Ipl_matches.head(1)

qualifier_round=Ipl_matches[['Season','MatchNumber','WinningTeam','Player_of_Match']]

qualifier_round[~qualifier_round.MatchNumber.str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# CH Gayle             1
# MS Dhoni             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# M Ntini              1
# Name: count, dtype: int64

# %%
Ipl_matches.head(1)
Ipl_matches['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# ipl er modde koto match khelse
# add posible jodi index same hoy

(Ipl_matches['Team1'].value_counts()+Ipl_matches['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# sorting value
movies.sort_values(by='imdb_rating',ascending=False,na_position='first')
# Out:
#                          title_x     imdb_id  \
# 41          Family of Thakurganj   tt8897986
# 1628                    Humsafar   tt2403201
# 62                Saand Ki Aankh   tt8108206
# 1435  Final Solution (2003 film)   tt0402178
# 58             Ghost (2019 film)   tt9378950
# ...                          ...         ...
# 331           Ek Kahani Julie Ki   tt7997334
# 407                  I Love Desi   tt4718678
# 479         Anuradha (2014 film)   tt3482198
# 472           Dee Saturday Night  tt10635372
# 70     Keep Safe Distance (film)   tt8876008
#
#                                             poster_path  \
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 62    https://upload.wikimedia.org/wikipedia/en/thum...
# 1435                                                NaN
# 58    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 331   https://upload.wikimedia.org/wikipedia/en/thum...
# 407   https://upload.wikimedia.org/wikipedia/en/thum...
# 479   https://upload.wikimedia.org/wikipedia/en/thum...
# 472   https://upload.wikimedia.org/wikipedia/en/thum...
# 70                                                  NaN
#
#                                               wiki_link               title_y  \
# 41    https://en.wikipedia.org/wiki/Family_of_Thakur...  Family of Thakurganj
# 1628             https://en.wikipedia.org/wiki/Humsafar              Humsafar
# 62         https://en.wikipedia.org/wiki/Saand_Ki_Aankh        Saand Ki Aankh
# 1435  https://en.wikipedia.org/wiki/Final_Solution_(...        Final Solution
# 58      https://en.wikipedia.org/wiki/Ghost_(2019_film)                 Ghost
# ...                                                 ...                   ...
# 331    https://en.wikipedia.org/wiki/Ek_Kahani_Julie_Ki    Ek Kahani Julie Ki
# 407           https://en.wikipedia.org/wiki/I_Love_Desi           I Love Desi
# 479   https://en.wikipedia.org/wiki/Anuradha_(2014_H...              Anuradha
# 472    https://en.wikipedia.org/wiki/Dee_Saturday_Night    Dee Saturday Night
# 70    https://en.wikipedia.org/wiki/Keep_Safe_Distan...    Keep Safe Distance
#
#             original_title  is_adult  year_of_release runtime  \
# 41    Family of Thakurganj         0             2019     127
# 1628              Humsafar         0             2011      35
# 62          Saand Ki Aankh         0             2019     146
# 1435        Final Solution         0             2004     218
# 58                   Ghost         0             2019     130
# ...                    ...       ...              ...     ...
# 331     Ek Kahani Julie Ki         0             2016     119
# 407            I Love Desi         0             2015      \N
# 479               Anuradha         0             2014      \N
# 472     Dee Saturday Night         0             2014      \N
# 70      Keep Safe Distance         0             2019     128
#
#                genres  imdb_rating  imdb_votes  \
# 41       Action|Drama          9.4         895
# 1628    Drama|Romance          9.0        2968
# 62    Biography|Drama          8.9        1902
# 1435      Documentary          8.7         333
# 58    Horror|Thriller          8.7        1379
# ...               ...          ...         ...
# 331             Drama          0.0           0
# 407    Comedy|Romance          0.0           0
# 479             Drama          0.0           0
# 472             Drama          0.0           0
# 70    Action|Thriller          0.0           0
#
#                                                   story  \
# 41    The film is based on small town of North India...
# 1628  Sara and Ashar are childhood friends who share...
# 62    Both over the age of 60  Chandro Tomar and Pra...
# 1435  The Final Solution is a 2003 documentary direc...
# 58    The story of the film follows Karan Khanna  a ...
# ...                                                 ...
# 331                                                 NaN
# 407                                                 NaN
# 479                                                 NaN
# 472                                                 NaN
# 70    Keep Safe Distance is an upcoming Indian thril...
#
#                                                 summary tagline  \
# 41    The film is based on small town of North India...     NaN
# 1628  Ashar and Khirad are forced to get married due...     NaN
# 62    Both over the age of 60  Chandro Tomar and Pra...     NaN
# 1435  The Final Solution is a 2003 documentary direc...     NaN
# 58    The story of the film follows Karan Khanna  a ...     NaN
# ...                                                 ...     ...
# 331                                        Add a Plot »     NaN
# 407                                        Add a Plot »     NaN
# 479                                        Add a Plot »     NaN
# 472                                        Add a Plot »     NaN
# 70    Keep Safe Distance is an upcoming Indian thril...     NaN
#
#                                                  actors  \
# 41    Jimmy Sheirgill|Mahie Gill|Nandish Singh|Prana...
# 1628                                        Fawad Khan|
# 62    Taapsee Pannu|Bhumi Pednekar|Prakash Jha|Viine...
# 1435                                                NaN
# 58    Sanaya Irani|Shivam Bhaargava|Vikram Bhatt|Ame...
# ...                                                 ...
# 331                                       Jimmy Sharma|
# 407   Shakti Anand|Arun Bali|Vedant Bali|Sunita Dhir...
# 479   Sachin Khedekar|Hrishitaa Bhatt|Manoj Joshi|Ki...
# 472                                                 NaN
# 70    Shahbaaz Khan|Adi Irani|Vikas Anand|Kiran Kuma...
#
#             wins_nominations                release_date Country  \
# 41                       NaN        19 July 2019 (India)   India
# 1628                     NaN       TV Series (2011–2012)   India
# 62              1 nomination       25 October 2019 (USA)   India
# 1435  5 wins & 2 nominations  13 February 2004 (Germany)   India
# 58                       NaN     18 October 2019 (India)   India
# ...                      ...                         ...     ...
# 331                      NaN                         NaN   India
# 407                      NaN                         NaN   India
# 479                      NaN                         NaN   India
# 472                      NaN                         NaN   India
# 70                       NaN                         NaN   India
#
#          LeadingActor
# 41    Jimmy Sheirgill
# 1628       Fawad Khan
# 62      Taapsee Pannu
# 1435              NaN
# 58       Sanaya Irani
# ...               ...
# 331      Jimmy Sharma
# 407      Shakti Anand
# 479   Sachin Khedekar
# 472               NaN
# 70      Shahbaaz Khan
#
# [1629 rows x 20 columns]

# %%
# MULTIPLE LINE SORT

movies.sort_values(by=['year_of_release','title_x'],ascending=[False,True])
# Out:
#                                    title_x     imdb_id  \
# 21                                22 Yards   tt9496212
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 10                                  Amavas   tt8396186
# 46                           Arjun Patiala   tt7881524
# 37                       Article 15 (film)  tt10324144
# ...                                    ...         ...
# 1573                   Yaadein (2001 film)   tt0248617
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1623                              Zubeidaa   tt0255713
#
#                                             poster_path  \
# 21    https://upload.wikimedia.org/wikipedia/en/thum...
# 26    https://upload.wikimedia.org/wikipedia/en/thum...
# 10    https://upload.wikimedia.org/wikipedia/en/thum...
# 46    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1573  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 21               https://en.wikipedia.org/wiki/22_Yards
# 26    https://en.wikipedia.org/wiki/Albert_Pinto_Ko_...
# 10                 https://en.wikipedia.org/wiki/Amavas
# 46          https://en.wikipedia.org/wiki/Arjun_Patiala
# 37      https://en.wikipedia.org/wiki/Article_15_(film)
# ...                                                 ...
# 1573  https://en.wikipedia.org/wiki/Yaadein_(2001_film)
# 1620  https://en.wikipedia.org/wiki/Yeh_Raaste_Hain_...
# 1622  https://en.wikipedia.org/wiki/Yeh_Teraa_Ghar_Y...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
#
#                                    title_y  \
# 21                                22 Yards
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?
# 10                                  Amavas
# 46                           Arjun Patiala
# 37                              Article 15
# ...                                    ...
# 1573                            Yaadein...
# 1620              Yeh Raaste Hain Pyaar Ke
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar
# 1625                  Yeh Zindagi Ka Safar
# 1623                              Zubeidaa
#
#                             original_title  is_adult  year_of_release runtime  \
# 21                                22 Yards         0             2019     126
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?         0             2019     100
# 10                                  Amavas         0             2019     134
# 46                           Arjun Patiala         0             2019     107
# 37                              Article 15         0             2019     130
# ...                                    ...       ...              ...     ...
# 1573                            Yaadein...         0             2001     171
# 1620              Yeh Raaste Hain Pyaar Ke         0             2001     149
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar         0             2001     175
# 1625                  Yeh Zindagi Ka Safar         0             2001     146
# 1623                              Zubeidaa         0             2001     153
#
#                        genres  imdb_rating  imdb_votes  \
# 21                      Sport          5.3         124
# 26                      Drama          4.8          56
# 10            Horror|Thriller          2.8         235
# 46              Action|Comedy          4.1         676
# 37                Crime|Drama          8.3       13417
# ...                       ...          ...         ...
# 1573    Drama|Musical|Romance          4.4        3034
# 1620            Drama|Romance          4.0         607
# 1622             Comedy|Drama          5.7         704
# 1625                    Drama          3.0         133
# 1623  Biography|Drama|History          6.2        1384
#
#                                                   story  \
# 21    A dramatic portrayal of a victorious tale of a...
# 26    Albert leaves his house one morning without te...
# 10    Far away from the bustle of the city  a young ...
# 46    Arjun Patiala(Diljit Dosanjh)has recently been...
# 37    In the rural heartlands of India  an upright p...
# ...                                                 ...
# 1573  Raj Singh Puri is best friends with L.K. Malho...
# 1620  Two con artistes and car thieves  Vicky (Ajay ...
# 1622  In debt; Dayashankar Pandey is forced to go to...
# 1625  Hindi pop-star  Sarina Devan  lives a wealthy ...
# 1623  The film begins with Riyaz (Rajat Kapoor)  Zub...
#
#                                                 summary  \
# 21    A dramatic portrayal of a victorious tale of a...
# 26    Albert Pinto goes missing one day and his girl...
# 10    The lives of a couple turn into a nightmare  a...
# 46    This spoof comedy narrates the story of a cop ...
# 37    In the rural heartlands of India  an upright p...
# ...                                                 ...
# 1573  Raj Singh Puri is best friends with L.K. Malho...
# 1620  Two con artistes and car thieves  Vicky (Ajay ...
# 1622  In debt; Dayashankar Pandey is forced to go to...
# 1625  A singer finds out she was adopted when the ed...
# 1623  Zubeidaa  an aspiring Muslim actress  marries ...
#
#                                      tagline  \
# 21                                       NaN
# 26                                       NaN
# 10                                       NaN
# 46                                       NaN
# 37    Farq Bahut Kar Liya| Ab Farq Laayenge.
# ...                                      ...
# 1573                  memories to cherish...
# 1620  Love is a journey... not a destination
# 1622                                     NaN
# 1625                                     NaN
# 1623                 The Story of a Princess
#
#                                                  actors  \
# 21    Barun Sobti|Rajit Kapur|Panchhi Bora|Kartikey ...
# 26                              Manav Kaul|Nandita Das|
# 10    Ali Asgar|Vivan Bhatena|Nargis Fakhri|Sachiin ...
# 46    Diljit Dosanjh|Kriti Sanon|Varun Sharma|Ronit ...
# 37    Ayushmann Khurrana|Nassar|Manoj Pahwa|Kumud Mi...
# ...                                                 ...
# 1573  Jackie Shroff|Hrithik Roshan|Kareena Kapoor|Am...
# 1620  Ajay Devgn|Madhuri Dixit|Preity Zinta|Vikram G...
# 1622  Sunil Shetty|Mahima Chaudhry|Paresh Rawal|Saur...
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1623  Karisma Kapoor|Rekha|Manoj Bajpayee|Rajit Kapo...
#
#              wins_nominations              release_date Country  \
# 21                        NaN     15 March 2019 (India)   India
# 26                        NaN     12 April 2019 (India)   India
# 10                        NaN   8 February 2019 (India)   India
# 46                        NaN        26 July 2019 (USA)   India
# 37                      1 win        28 June 2019 (USA)   India
# ...                       ...                       ...     ...
# 1573             1 nomination      27 June 2001 (India)   India
# 1620                      NaN    10 August 2001 (India)   India
# 1622             1 nomination   12 October 2001 (India)   India
# 1625                      NaN  16 November 2001 (India)   India
# 1623  3 wins & 13 nominations   19 January 2001 (India)   India
#
#             LeadingActor
# 21           Barun Sobti
# 26            Manav Kaul
# 10             Ali Asgar
# 46        Diljit Dosanjh
# 37    Ayushmann Khurrana
# ...                  ...
# 1573       Jackie Shroff
# 1620          Ajay Devgn
# 1622        Sunil Shetty
# 1625       Ameesha Patel
# 1623      Karisma Kapoor
#
# [1629 rows x 20 columns]

# %%
# pd.unique

Ipl_matches.Season.unique().shape[0]
# Out:
# 15

# %%
# nunique not count nan value

Ipl_matches.method.nunique()
Ipl_matches.method[~Ipl_matches.method.isnull()]
# Out:
# 282    D/L
# 296    D/L
# 308    D/L
# 316    D/L
# 383    D/L
# 384    D/L
# 389    D/L
# 411    D/L
# 441    D/L
# 472    D/L
# 520    D/L
# 717    D/L
# 728    D/L
# 757    D/L
# 860    D/L
# 886    D/L
# 889    D/L
# 908    D/L
# 910    D/L
# Name: method, dtype: object

# %% [markdown]
# #**Missing value handling**

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...                                                 ...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
#                             title_y                 original_title  is_adult  \
# 0          Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                     Battalion 609                  Battalion 609         0
# 2     The Accidental Prime Minister  The Accidental Prime Minister         0
# 3                   Why Cheat India                Why Cheat India         0
# 4                   Evening Shadows                Evening Shadows         0
# ...                             ...                            ...       ...
# 1624          Tera Mera Saath Rahen          Tera Mera Saath Rahen         0
# 1625           Yeh Zindagi Ka Safar           Yeh Zindagi Ka Safar         0
# 1626                Sabse Bada Sukh                Sabse Bada Sukh         0
# 1627                          Daaka                          Daaka         0
# 1628                       Humsafar                       Humsafar         0
#
#       year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0                2019     138  Action|Drama|War          8.4       35112
# 1                2019     131               War          4.1          73
# 2                2019     112   Biography|Drama          6.1        5549
# 3                2019     121       Crime|Drama          6.0        1891
# 4                2018     102             Drama          7.3         280
# ...               ...     ...               ...          ...         ...
# 1624             2001     148             Drama          4.9         278
# 1625             2001     146             Drama          3.0         133
# 1626             2018      \N      Comedy|Drama          6.1          13
# 1627             2019     136            Action          7.4          38
# 1628             2011      35     Drama|Romance          9.0        2968
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 1     The story revolves around a cricket match betw...
# 2     Based on the memoir by Indian policy analyst S...
# 3     The movie focuses on existing malpractices in ...
# 4     While gay rights and marriage equality has bee...
# ...                                                 ...
# 1624  Raj Dixit lives with his younger brother  Rahu...
# 1625  Hindi pop-star  Sarina Devan  lives a wealthy ...
# 1626  Village born Lalloo re-locates to Bombay  and ...
# 1627  Shinda tries robbing a bank so he can be wealt...
# 1628  Sara and Ashar are childhood friends who share...
#
#                                                 summary tagline  \
# 0     Indian army special forces execute a covert op...     NaN
# 1     The story of Battalion 609 revolves around a c...     NaN
# 2     Explores Manmohan Singh's tenure as the Prime ...     NaN
# 3     The movie focuses on existing malpractices in ...     NaN
# 4     Under the 'Evening Shadows'  truth often plays...     NaN
# ...                                                 ...     ...
# 1624  A man is torn between his handicapped brother ...     NaN
# 1625  A singer finds out she was adopted when the ed...     NaN
# 1626  Village born Lalloo re-locates to Bombay  and ...     NaN
# 1627  Shinda tries robbing a bank so he can be wealt...     NaN
# 1628  Ashar and Khirad are forced to get married due...     NaN
#
#                                                  actors  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                          Gippy Grewal|Zareen Khan|
# 1628                                        Fawad Khan|
#
#             wins_nominations              release_date Country  \
# 0                     4 wins     11 January 2019 (USA)   India
# 1                        NaN   11 January 2019 (India)   India
# 2                        NaN     11 January 2019 (USA)   India
# 3                        NaN     18 January 2019 (USA)   India
# 4     17 wins & 1 nomination   11 January 2019 (India)   India
# ...                      ...                       ...     ...
# 1624                     NaN   7 November 2001 (India)   India
# 1625                     NaN  16 November 2001 (India)   India
# 1626                     NaN                       NaN   India
# 1627                     NaN     1 November 2019 (USA)   India
# 1628                     NaN     TV Series (2011–2012)   India
#
#           LeadingActor
# 0        Vicky Kaushal
# 1          Vicky Ahuja
# 2          Anupam Kher
# 3        Emraan Hashmi
# 4     Mona Ambegaonkar
# ...                ...
# 1624        Ajay Devgn
# 1625     Ameesha Patel
# 1626       Vijay Arora
# 1627      Gippy Grewal
# 1628        Fawad Khan
#
# [1629 rows x 20 columns]

# %%
# dropna
# drop all row which have missing value
movies.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
#  16  wins_nominations  298 non-null    object
#  17  release_date      298 non-null    object
#  18  Country           298 non-null    object
#  19  LeadingActor      298 non-null    object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 48.9+ KB

# %%
# if every columns has missing value then drop it
movies.dropna(how='all').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
#  16  wins_nominations  707 non-null    object
#  17  release_date      1522 non-null   object
#  18  Country           1629 non-null   object
#  19  LeadingActor      1624 non-null   object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 254.7+ KB

# %%
# if particular columns has missing value(or operation work)
movies.dropna(subset=['actors','year_of_release'])
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...                                                 ...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
#                             title_y                 original_title  is_adult  \
# 0          Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                     Battalion 609                  Battalion 609         0
# 2     The Accidental Prime Minister  The Accidental Prime Minister         0
# 3                   Why Cheat India                Why Cheat India         0
# 4                   Evening Shadows                Evening Shadows         0
# ...                             ...                            ...       ...
# 1624          Tera Mera Saath Rahen          Tera Mera Saath Rahen         0
# 1625           Yeh Zindagi Ka Safar           Yeh Zindagi Ka Safar         0
# 1626                Sabse Bada Sukh                Sabse Bada Sukh         0
# 1627                          Daaka                          Daaka         0
# 1628                       Humsafar                       Humsafar         0
#
#       year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0                2019     138  Action|Drama|War          8.4       35112
# 1                2019     131               War          4.1          73
# 2                2019     112   Biography|Drama          6.1        5549
# 3                2019     121       Crime|Drama          6.0        1891
# 4                2018     102             Drama          7.3         280
# ...               ...     ...               ...          ...         ...
# 1624             2001     148             Drama          4.9         278
# 1625             2001     146             Drama          3.0         133
# 1626             2018      \N      Comedy|Drama          6.1          13
# 1627             2019     136            Action          7.4          38
# 1628             2011      35     Drama|Romance          9.0        2968
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 1     The story revolves around a cricket match betw...
# 2     Based on the memoir by Indian policy analyst S...
# 3     The movie focuses on existing malpractices in ...
# 4     While gay rights and marriage equality has bee...
# ...                                                 ...
# 1624  Raj Dixit lives with his younger brother  Rahu...
# 1625  Hindi pop-star  Sarina Devan  lives a wealthy ...
# 1626  Village born Lalloo re-locates to Bombay  and ...
# 1627  Shinda tries robbing a bank so he can be wealt...
# 1628  Sara and Ashar are childhood friends who share...
#
#                                                 summary tagline  \
# 0     Indian army special forces execute a covert op...     NaN
# 1     The story of Battalion 609 revolves around a c...     NaN
# 2     Explores Manmohan Singh's tenure as the Prime ...     NaN
# 3     The movie focuses on existing malpractices in ...     NaN
# 4     Under the 'Evening Shadows'  truth often plays...     NaN
# ...                                                 ...     ...
# 1624  A man is torn between his handicapped brother ...     NaN
# 1625  A singer finds out she was adopted when the ed...     NaN
# 1626  Village born Lalloo re-locates to Bombay  and ...     NaN
# 1627  Shinda tries robbing a bank so he can be wealt...     NaN
# 1628  Ashar and Khirad are forced to get married due...     NaN
#
#                                                  actors  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                          Gippy Grewal|Zareen Khan|
# 1628                                        Fawad Khan|
#
#             wins_nominations              release_date Country  \
# 0                     4 wins     11 January 2019 (USA)   India
# 1                        NaN   11 January 2019 (India)   India
# 2                        NaN     11 January 2019 (USA)   India
# 3                        NaN     18 January 2019 (USA)   India
# 4     17 wins & 1 nomination   11 January 2019 (India)   India
# ...                      ...                       ...     ...
# 1624                     NaN   7 November 2001 (India)   India
# 1625                     NaN  16 November 2001 (India)   India
# 1626                     NaN                       NaN   India
# 1627                     NaN     1 November 2019 (USA)   India
# 1628                     NaN     TV Series (2011–2012)   India
#
#           LeadingActor
# 0        Vicky Kaushal
# 1          Vicky Ahuja
# 2          Anupam Kher
# 3        Emraan Hashmi
# 4     Mona Ambegaonkar
# ...                ...
# 1624        Ajay Devgn
# 1625     Ameesha Patel
# 1626       Vijay Arora
# 1627      Gippy Grewal
# 1628        Fawad Khan
#
# [1624 rows x 20 columns]

# %%
# find last vk play agiest delhi

Ipl_matches['allplayer']=Ipl_matches.Team1Players.add(Ipl_matches.Team2Players)

def isvkplay(allplayer,x='V Kohli'):
  return 'V Kohli' in allplayer

Ipl_matches['isplayVk']=Ipl_matches['allplayer'].apply(isvkplay)

isvk=Ipl_matches[Ipl_matches.isplayVk==True]

isvk[isvk.City=='Delhi'].drop_duplicates(subset=['City','isplayVk'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                          allplayer  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     isplayVk
# 208     True
#
# [1 rows x 22 columns]

# %% [markdown]
# # *Class of groupBy most important class \\*
#
# ---

# %%
# groupby

movie=pd.read_csv('/content/imdb-top-1000.csv')

movie.head(5)
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
genre=movie.groupby('Genre')

print(genre.size())

genre.mean(numeric_only=True)

genre.sum(numeric_only=True)

genre.max(numeric_only=True)

genre.min(numeric_only=True)

genre.std(numeric_only=True)

genre.median(numeric_only=True)

genre.var(numeric_only=True)
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64
#                Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# Genre
# Action      812.290222     0.092573  1.874429e+11  5.092802e+16  154.287501
# Adventure  1110.043818     0.052799  9.071442e+10  2.881653e+16  152.408730
# Animation   211.134598     0.064121  6.873480e+10  4.375794e+16   77.680360
# Biography   650.987983     0.071364  7.359511e+10  1.858452e+16  121.620902
# Comedy      526.528697     0.052336  3.559017e+10  3.788913e+16  139.929032
# Crime       766.693528     0.112545  1.398758e+11  2.468643e+16  171.586474
# Drama       769.534770     0.071411  9.336335e+10  4.845123e+16  162.427040
# Family      112.500000     0.000000  1.877128e+10  9.292815e+16  288.000000
# Fantasy     162.000000     0.020000  4.919130e+08  5.786433e+15         NaN
# Film-Noir    16.000000     0.023333  2.986522e+09  4.968096e+15    2.333333
# Horror      185.090909     0.096909  5.517026e+10  9.930155e+15  236.000000
# Mystery     209.537879     0.096591  1.637189e+11  2.457132e+16  346.125000
# Thriller           NaN          NaN           NaN           NaN         NaN
# Western     294.250000     0.176667  6.942675e+10  1.514441e+14   81.583333

# %%
# find the top 3 most income genre
movie.groupby('Genre').sum(numeric_only=True)['Gross'].sort_values(ascending=False)[:3]
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# you have to find the that genre which has highest Imdb_rating

movie.groupby('Genre').max(numeric_only=True)['IMDB_Rating'].sort_values(ascending=False)[0:1]
# Out:
# Genre
# Drama    9.3
# Name: IMDB_Rating, dtype: float64

# %%
#find most popular director

movie.groupby('Director').sum(numeric_only=True)['No_of_Votes'].sort_values(ascending=False)[:1]
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %% [markdown]
# # Group by attribute

# %%
len(movie.groupby('Genre'))
# Out:
# 14

# %%
movie.groupby('Genre').nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# Mystery              12             11       10            8        10     11
# Thriller              1              1        1            1         1      1
# Western               4              4        4            4         2      2
#
#            No_of_Votes  Gross  Metascore
# Genre
# Action             172    172         50
# Adventure           72     72         33
# Animation           82     82         29
# Biography           88     88         40
# Comedy             155    155         44
# Crime              107    107         39
# Drama              288    287         52
# Family               2      2          2
# Fantasy              2      2          0
# Film-Noir            3      3          3
# Horror              11     11          9
# Mystery             12     12          7
# Thriller             1      1          1
# Western              4      4          4

# %%
# size-> bole dei ekta group er modde koto gula group ase

movie.groupby('Genre').size()

movie['Genre'].value_counts()
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
genre=movie.groupby('Genre')

genre.first()
genre.last()

genre.nth(6)
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 16   Star Wars: Episode V - The Empire Strikes Back          1980      124
# 27                                            Se7en          1995      127
# 32                            It's a Wonderful Life          1946      130
# 66                                           WALL·E          2008       98
# 83                               The Great Dictator          1940      125
# 102                                      Braveheart          1995      178
# 118                              North by Northwest          1959      136
# 420                                          Sleuth          1972      138
# 724                                         Get Out          2017      104
#
#          Genre  IMDB_Rating              Director             Star1  \
# 16      Action          8.7        Irvin Kershner       Mark Hamill
# 27       Crime          8.6         David Fincher    Morgan Freeman
# 32       Drama          8.6           Frank Capra     James Stewart
# 66   Animation          8.4        Andrew Stanton         Ben Burtt
# 83      Comedy          8.4       Charles Chaplin   Charles Chaplin
# 102  Biography          8.3            Mel Gibson        Mel Gibson
# 118  Adventure          8.3      Alfred Hitchcock        Cary Grant
# 420    Mystery          8.0  Joseph L. Mankiewicz  Laurence Olivier
# 724     Horror          7.7          Jordan Peele    Daniel Kaluuya
#
#      No_of_Votes        Gross  Metascore
# 16       1159315  290475067.0       82.0
# 27       1445096  100125643.0       65.0
# 32        405801   82385199.0       89.0
# 66        999790  223808164.0       95.0
# 83        203150     288475.0        NaN
# 102       959181   75600000.0       68.0
# 118       299198   13275000.0       98.0
# 420        44748    4081254.0        NaN
# 724       492851  176040665.0       85.0

# %%
# particular column er shob show korbo
genre.get_group('Horror')

# genre.groups
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
# 707             The Innocents          1961      100  Horror          7.8
# 724                   Get Out          2017      104  Horror          7.7
# 844                 Halloween          1978       91  Horror          7.7
# 876         The Invisible Man          1933       71  Horror          7.7
# 932                       Saw          2004      103  Horror          7.6
# 948                The Others          2001      101  Horror          7.6
#
#                Director             Star1  No_of_Votes        Gross  Metascore
# 49     Alfred Hitchcock   Anthony Perkins       604211   32000000.0       97.0
# 75         Ridley Scott  Sigourney Weaver       787806   78900000.0       89.0
# 271      John Carpenter      Kurt Russell       371271   13782838.0       57.0
# 419    William Friedkin     Ellen Burstyn       362393  232906145.0       81.0
# 544    George A. Romero       Duane Jones       116557      89029.0       89.0
# 707        Jack Clayton      Deborah Kerr        27007    2616000.0       88.0
# 724        Jordan Peele    Daniel Kaluuya       492851  176040665.0       85.0
# 844      John Carpenter  Donald Pleasence       233106   47000000.0       87.0
# 876         James Whale      Claude Rains        30683  298791505.0       87.0
# 932           James Wan        Cary Elwes       379020   56000369.0       46.0
# 948  Alejandro Amenábar     Nicole Kidman       337651   96522687.0       74.0

# %%
# protigroup er modde shob numeric column ke show kore
genre.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# Horror       11.0  102.090909  13.604812   71.0   98.00  103.0  109.00  122.0
# Mystery      12.0  119.083333  14.475423   96.0  110.75  117.5  130.25  138.0
# Thriller      1.0  108.000000        NaN  108.0  108.00  108.0  108.00  108.0
# Western       4.0  148.250000  17.153717  132.0  134.25  148.0  162.00  165.0
#
#           IMDB_Rating            ...         Gross              Metascore  \
#                 count      mean  ...           75%          max     count
# Genre                            ...
# Action          172.0  7.949419  ...  2.674437e+08  936662225.0     143.0
# Adventure        72.0  7.937500  ...  1.998070e+08  874211619.0      64.0
# Animation        82.0  7.930488  ...  2.520612e+08  873839108.0      75.0
# Biography        88.0  7.938636  ...  9.829924e+07  753585104.0      79.0
# Comedy          155.0  7.901290  ...  8.107809e+07  886752933.0     125.0
# Crime           107.0  8.016822  ...  7.102163e+07  790482117.0      87.0
# Drama           289.0  7.957439  ...  1.164461e+08  924558264.0     241.0
# Family            2.0  7.800000  ...  3.273329e+08  435110554.0       2.0
# Fantasy           2.0  8.000000  ...  4.182577e+08  445151978.0       0.0
# Film-Noir         3.0  7.966667  ...  6.273068e+07  123353292.0       3.0
# Horror           11.0  7.909091  ...  1.362817e+08  298791505.0      11.0
# Mystery          12.0  7.975000  ...  1.310949e+08  474203697.0       8.0
# Thriller          1.0  7.800000  ...  1.755074e+07   17550741.0       1.0
# Western           4.0  8.350000  ...  1.920000e+07   31800000.0       4.0
#
#
#                 mean        std   min    25%   50%    75%    max
# Genre
# Action     73.419580  12.421252  33.0  65.00  74.0  82.00   98.0
# Adventure  78.437500  12.345393  41.0  69.75  80.5  87.25  100.0
# Animation  81.093333   8.813646  61.0  75.00  82.0  87.50   96.0
# Biography  76.240506  11.028187  48.0  70.50  76.0  84.50   97.0
# Comedy     78.720000  11.829160  45.0  72.00  79.0  88.00   99.0
# Crime      77.080460  13.099102  47.0  69.50  77.0  87.00  100.0
# Drama      79.701245  12.744687  28.0  72.00  82.0  89.00  100.0
# Family     79.000000  16.970563  67.0  73.00  79.0  85.00   91.0
# Fantasy          NaN        NaN   NaN    NaN   NaN    NaN    NaN
# Film-Noir  95.666667   1.527525  94.0  95.00  96.0  96.50   97.0
# Horror     80.000000  15.362291  46.0  77.50  87.0  88.50   97.0
# Mystery    79.125000  18.604435  52.0  65.25  77.0  98.50  100.0
# Thriller   81.000000        NaN  81.0  81.00  81.0  81.00   81.0
# Western    78.250000   9.032349  69.0  72.75  77.0  82.50   90.0
#
# [14 rows x 40 columns]

# %%
genre.sample(2,replace=True)
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 496                Letters from Iwo Jima          2006      141     Action
# 663                         The Fugitive          1993      130     Action
# 366                             G.O.R.A.          2004      127  Adventure
# 675           Back to the Future Part II          1989      108  Adventure
# 771                              Tangled          2010      100  Animation
# 409               Tenkû no shiro Rapyuta          1986      125  Animation
# 606               Straight Outta Compton          2015      147  Biography
# 684                   The Killing Fields          1984      141  Biography
# 558               Miracle on 34th Street          1947       96     Comedy
# 472                          Sing Street          2016      106     Comedy
# 363                              Bin-jip          2004       88      Crime
# 895                             Leviafan          2014      140      Crime
# 124                         Citizen Kane          1941      119      Drama
# 517                        Boogie Nights          1997      155      Drama
# 698  Willy Wonka & the Chocolate Factory          1971      100     Family
# 688           E.T. the Extra-Terrestrial          1982      115     Family
# 321         Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 321         Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 712                    Shadow of a Doubt          1943      108  Film-Noir
# 712                    Shadow of a Doubt          1943      108  Film-Noir
# 75                                 Alien          1979      117     Horror
# 844                            Halloween          1978       91     Horror
# 69                               Memento          2000      113    Mystery
# 145                       Shutter Island          2010      138    Mystery
# 700                      Wait Until Dark          1967      108   Thriller
# 700                      Wait Until Dark          1967      108   Thriller
# 12       Il buono, il brutto, il cattivo          1966      161    Western
# 115           Per qualche dollaro in più          1965      132    Western
#
#      IMDB_Rating              Director                Star1  No_of_Votes  \
# 496          7.9        Clint Eastwood         Ken Watanabe       154011
# 663          7.8          Andrew Davis        Harrison Ford       267684
# 366          8.0      Ömer Faruk Sorak           Cem Yilmaz        56960
# 675          7.8       Robert Zemeckis       Michael J. Fox       481918
# 771          7.7          Nathan Greno         Byron Howard       405922
# 409          8.0        Hayao Miyazaki        Mayumi Tanaka       150140
# 606          7.8          F. Gary Gray   O'Shea Jackson Jr.       179264
# 684          7.8          Roland Joffé        Sam Waterston        51585
# 558          7.9         George Seaton         Edmund Gwenn        41625
# 472          7.9           John Carney   Ferdia Walsh-Peelo        85109
# 363          8.0            Ki-duk Kim        Seung-Yun Lee        50610
# 895          7.6    Andrey Zvyagintsev  Aleksey Serebryakov        49397
# 124          8.3          Orson Welles         Orson Welles       403351
# 517          7.9  Paul Thomas Anderson        Mark Wahlberg       239473
# 698          7.8            Mel Stuart          Gene Wilder       178731
# 688          7.8      Steven Spielberg         Henry Thomas       372490
# 321          8.1          Robert Wiene        Werner Krauss        57428
# 321          8.1          Robert Wiene        Werner Krauss        57428
# 712          7.8      Alfred Hitchcock        Teresa Wright        59556
# 712          7.8      Alfred Hitchcock        Teresa Wright        59556
# 75           8.4          Ridley Scott     Sigourney Weaver       787806
# 844          7.7        John Carpenter     Donald Pleasence       233106
# 69           8.4     Christopher Nolan           Guy Pearce      1125712
# 145          8.2       Martin Scorsese    Leonardo DiCaprio      1129894
# 700          7.8         Terence Young       Audrey Hepburn        27733
# 700          7.8         Terence Young       Audrey Hepburn        27733
# 12           8.8          Sergio Leone       Clint Eastwood       688390
# 115          8.3          Sergio Leone       Clint Eastwood       232772
#
#            Gross  Metascore
# 496   13756082.0       89.0
# 663  183875760.0       87.0
# 366  196206077.0        NaN
# 675  118500000.0       57.0
# 771  200821936.0       71.0
# 409  715920290.0       78.0
# 606  161197785.0       72.0
# 684   34700291.0       76.0
# 558    2650000.0       88.0
# 472    3237118.0       79.0
# 363     238507.0       72.0
# 895    1092800.0       92.0
# 124    1585634.0      100.0
# 517   26400640.0       85.0
# 698    4000000.0       67.0
# 688  435110554.0       91.0
# 321  337574718.0        NaN
# 321  337574718.0        NaN
# 712  123353292.0       94.0
# 712  123353292.0       94.0
# 75    78900000.0       89.0
# 844   47000000.0       87.0
# 69    25544867.0       80.0
# 145  128012934.0       63.0
# 700   17550741.0       81.0
# 700   17550741.0       81.0
# 12     6100000.0       90.0
# 115   15000000.0       74.0

# %%
genre.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# Mystery              12             11       10            8        10     11
# Thriller              1              1        1            1         1      1
# Western               4              4        4            4         2      2
#
#            No_of_Votes  Gross  Metascore
# Genre
# Action             172    172         50
# Adventure           72     72         33
# Animation           82     82         29
# Biography           88     88         40
# Comedy             155    155         44
# Crime              107    107         39
# Drama              288    287         52
# Family               2      2          2
# Fantasy              2      2          0
# Film-Noir            3      3          3
# Horror              11     11          9
# Mystery             12     12          7
# Thriller             1      1          1
# Western              4      4          4

# %%
# most important agg function
bx=genre.agg(
    {
        'IMDB_Rating':'mean',
        'No_of_Votes':'max',
        'Gross':'max',
        'Released_Year':'min'
    }
)['Gross'].plot(kind='bar',figsize=(10,6))
for i, bar in enumerate(bx.patches):
    value = bar.get_height()  # প্রত্যেক বারের height মানে Gross value
    bx.text(                     # এখানে bx-ই axes object
        bar.get_x() + bar.get_width()/2,  # X-অক্ষের মাঝখানে
        value,                             # Y-অক্ষ: বারের টপ
        f'    {value:,.0f}',                   # সুন্দর করে কমা সহ ফরম্যাট করা
        ha='center',
        va='bottom',
        fontsize=8,
        rotation=90
    )

# %%
n_columns=movie.select_dtypes(include=np.number).columns

genre[n_columns].agg(['mean','max','min'])
# Out:
#               Runtime           IMDB_Rating              No_of_Votes           \
#                  mean  max  min        mean  max  min           mean      max
# Genre
# Action     129.046512  321   45    7.949419  9.0  7.6  420246.581395  2303232
# Adventure  134.111111  228   88    7.937500  8.6  7.6  313557.819444  1512360
# Animation   99.585366  137   71    7.930488  8.6  7.6  268032.073171   999790
# Biography  136.022727  209   93    7.938636  8.9  7.6  272805.045455  1213505
# Comedy     112.129032  188   68    7.901290  8.6  7.6  178195.658065   939631
# Crime      126.392523  229   80    8.016822  9.2  7.6  313398.271028  1826188
# Drama      124.737024  242   64    7.957439  9.3  7.6  212343.612457  2343110
# Family     107.500000  115  100    7.800000  7.8  7.8  275610.500000   372490
# Fantasy     85.000000   94   76    8.000000  8.1  7.9   73111.000000    88794
# Film-Noir  104.000000  108  100    7.966667  8.1  7.8  122405.000000   158731
# Horror     102.090909  122   71    7.909091  8.5  7.6  340232.363636   787806
# Mystery    119.083333  138   96    7.975000  8.4  7.6  350250.333333  1129894
# Thriller   108.000000  108  108    7.800000  7.8  7.8   27733.000000    27733
# Western    148.250000  165  132    8.350000  8.8  7.8  322416.250000   688390
#
#                           Gross                            Metascore         \
#               min          mean          max          min       mean    max
# Genre
# Action      25312  1.897224e+08  936662225.0       3296.0  73.419580   98.0
# Adventure   29999  1.319017e+08  874211619.0      61001.0  78.437500  100.0
# Animation   25229  1.784326e+08  873839108.0     128985.0  81.093333   96.0
# Biography   27254  9.404952e+07  753585104.0      21877.0  76.240506   97.0
# Comedy      26337  1.010572e+08  886752933.0       1305.0  78.720000   99.0
# Crime       27712  7.899656e+07  790482117.0       6013.0  77.080460  100.0
# Drama       25088  1.225259e+08  924558264.0       3600.0  79.701245  100.0
# Family     178731  2.195553e+08  435110554.0    4000000.0  79.000000   91.0
# Fantasy     57428  3.913633e+08  445151978.0  337574718.0        NaN    NaN
# Film-Noir   59556  4.197018e+07  123353292.0     449191.0  95.666667   97.0
# Horror      27007  9.405902e+07  298791505.0      89029.0  80.000000   97.0
# Mystery     33982  1.047014e+08  474203697.0    1035953.0  79.125000  100.0
# Thriller    27733  1.755074e+07   17550741.0   17550741.0  81.000000   81.0
# Western     65659  1.455538e+07   31800000.0    5321508.0  78.250000   90.0
#
#
#             min
# Genre
# Action     33.0
# Adventure  41.0
# Animation  61.0
# Biography  48.0
# Comedy     45.0
# Crime      47.0
# Drama      28.0
# Family     67.0
# Fantasy     NaN
# Film-Noir  94.0
# Horror     46.0
# Mystery    52.0
# Thriller   81.0
# Western    69.0

# %%
# loop using in group

# find the highest rating movie in that group
df=pd.DataFrame(columns=movie.columns)
for group,data in genre:
  print(type(group),type(data))
  top_rating=(data[data.IMDB_Rating==data.IMDB_Rating.max()])
  df=pd.concat([df,top_rating])
df
# Out:
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# /tmp/ipython-input-378650557.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df=pd.concat([df,top_rating])
#                             Series_Title Released_Year Runtime      Genre  \
# 2                        The Dark Knight          2008     152     Action
# 21                          Interstellar          2014     169  Adventure
# 23         Sen to Chihiro no kamikakushi          2001     125  Animation
# 7                       Schindler's List          1993     195  Biography
# 19                          Gisaengchung          2019     132     Comedy
# 26                       La vita è bella          1997     116     Comedy
# 1                          The Godfather          1972     175      Crime
# 0               The Shawshank Redemption          1994     142      Drama
# 688           E.T. the Extra-Terrestrial          1982     115     Family
# 698  Willy Wonka & the Chocolate Factory          1971     100     Family
# 321         Das Cabinet des Dr. Caligari          1920      76    Fantasy
# 309                        The Third Man          1949     104  Film-Noir
# 49                                Psycho          1960     109     Horror
# 69                               Memento          2000     113    Mystery
# 81                           Rear Window          1954     112    Mystery
# 700                      Wait Until Dark          1967     108   Thriller
# 12       Il buono, il brutto, il cattivo          1966     161    Western
#
#      IMDB_Rating              Director                Star1 No_of_Votes  \
# 2            9.0     Christopher Nolan       Christian Bale     2303232
# 21           8.6     Christopher Nolan  Matthew McConaughey     1512360
# 23           8.6        Hayao Miyazaki        Daveigh Chase      651376
# 7            8.9      Steven Spielberg          Liam Neeson     1213505
# 19           8.6          Bong Joon Ho         Kang-ho Song      552778
# 26           8.6       Roberto Benigni      Roberto Benigni      623629
# 1            9.2  Francis Ford Coppola        Marlon Brando     1620367
# 0            9.3        Frank Darabont          Tim Robbins     2343110
# 688          7.8      Steven Spielberg         Henry Thomas      372490
# 698          7.8            Mel Stuart          Gene Wilder      178731
# 321          8.1          Robert Wiene        Werner Krauss       57428
# 309          8.1            Carol Reed         Orson Welles      158731
# 49           8.5      Alfred Hitchcock      Anthony Perkins      604211
# 69           8.4     Christopher Nolan           Guy Pearce     1125712
# 81           8.4      Alfred Hitchcock        James Stewart      444074
# 700          7.8         Terence Young       Audrey Hepburn       27733
# 12           8.8          Sergio Leone       Clint Eastwood      688390
#
#            Gross  Metascore
# 2    534858444.0       84.0
# 21   188020017.0       74.0
# 23    10055859.0       96.0
# 7     96898818.0       94.0
# 19    53367844.0       96.0
# 26    57598247.0       59.0
# 1    134966411.0      100.0
# 0     28341469.0       80.0
# 688  435110554.0       91.0
# 698    4000000.0       67.0
# 321  337574718.0        NaN
# 309     449191.0       97.0
# 49    32000000.0       97.0
# 69    25544867.0       80.0
# 81    36764313.0      100.0
# 700   17550741.0       81.0
# 12     6100000.0       90.0

# %%
# combain 2 groups
duo = movie.groupby(['Director', 'Star1'])
duo['Gross'].sum().sort_values(ascending=False)
# Out:
# Director              Star1
# Akira Kurosawa        Toshirô Mifune     2.999877e+09
# Anthony Russo         Joe Russo          2.205039e+09
# Billy Wilder          William Holden     1.286779e+09
# Christopher Nolan     Christian Bale     1.242940e+09
# Werner Herzog         Klaus Kinski       1.124605e+09
#                                              ...
# Jeong-beom Lee        Won Bin            6.460000e+03
# Shane Meadows         Paddy Considine    6.013000e+03
# Jaco Van Dormael      Jared Leto         3.600000e+03
# Thomas Jahn           Til Schweiger      3.296000e+03
# Anders Thomas Jensen  Ulrich Thomsen     1.305000e+03
# Name: Gross, Length: 898, dtype: float64

# %%
best_mataScore=movie.groupby(['Star1','Genre'])

best_mataScore.Metascore.mean().reset_index().sort_values(by='Metascore',ascending=False)
# Out:
#                 Star1      Genre  Metascore
# 606     Peter O'Toole  Adventure      100.0
# 590      Orson Welles      Drama      100.0
# 77        Bertil Guve      Drama      100.0
# 230    Ellar Coltrane      Drama      100.0
# 329   Humphrey Bogart      Drama      100.0
# ..                ...        ...        ...
# 807    William Holden      Drama        NaN
# 812           Won Bin     Action        NaN
# 815              Yash     Action        NaN
# 826    Çetin Tekindor      Drama        NaN
# 828  Ömer Faruk Sorak     Comedy        NaN
#
# [829 rows x 3 columns]

# %%
# agg

n_columns=movie.select_dtypes(include=np.number).columns
duo[n_columns].agg(['min','max','mean'])
# Out:
#                                    Runtime             IMDB_Rating            \
#                                        min  max   mean         min  max mean
# Director            Star1
# Aamir Khan          Amole Gupte        165  165  165.0         8.4  8.4  8.4
# Aaron Sorkin        Eddie Redmayne     129  129  129.0         7.8  7.8  7.8
# Abdellatif Kechiche Léa Seydoux        180  180  180.0         7.7  7.7  7.7
# Abhishek Chaubey    Shahid Kapoor      148  148  148.0         7.8  7.8  7.8
# Abhishek Kapoor     Amit Sadh          130  130  130.0         7.7  7.7  7.7
# ...                                    ...  ...    ...         ...  ...  ...
# Zaza Urushadze      Lembit Ulfsak       87   87   87.0         8.2  8.2  8.2
# Zoya Akhtar         Hrithik Roshan     155  155  155.0         8.1  8.1  8.1
#                     Vijay Varma        154  154  154.0         8.0  8.0  8.0
# Çagan Irmak         Çetin Tekindor     112  112  112.0         8.3  8.3  8.3
# Ömer Faruk Sorak    Cem Yilmaz         127  127  127.0         8.0  8.0  8.0
#
#                                    No_of_Votes                          Gross  \
#                                            min     max      mean          min
# Director            Star1
# Aamir Khan          Amole Gupte         168895  168895  168895.0    1223869.0
# Aaron Sorkin        Eddie Redmayne       89896   89896   89896.0  853090410.0
# Abdellatif Kechiche Léa Seydoux         138741  138741  138741.0    2199675.0
# Abhishek Chaubey    Shahid Kapoor        27175   27175   27175.0  218428303.0
# Abhishek Kapoor     Amit Sadh            32628   32628   32628.0    1122527.0
# ...                                        ...     ...       ...          ...
# Zaza Urushadze      Lembit Ulfsak        40382   40382   40382.0     144501.0
# Zoya Akhtar         Hrithik Roshan       67927   67927   67927.0    3108485.0
#                     Vijay Varma          31886   31886   31886.0    5566534.0
# Çagan Irmak         Çetin Tekindor       78925   78925   78925.0  461855363.0
# Ömer Faruk Sorak    Cem Yilmaz           56960   56960   56960.0  196206077.0
#
#                                                              Metascore        \
#                                             max         mean       min   max
# Director            Star1
# Aamir Khan          Amole Gupte       1223869.0    1223869.0       NaN   NaN
# Aaron Sorkin        Eddie Redmayne  853090410.0  853090410.0      77.0  77.0
# Abdellatif Kechiche Léa Seydoux       2199675.0    2199675.0      89.0  89.0
# Abhishek Chaubey    Shahid Kapoor   218428303.0  218428303.0       NaN   NaN
# Abhishek Kapoor     Amit Sadh         1122527.0    1122527.0      40.0  40.0
# ...                                         ...          ...       ...   ...
# Zaza Urushadze      Lembit Ulfsak      144501.0     144501.0      73.0  73.0
# Zoya Akhtar         Hrithik Roshan    3108485.0    3108485.0       NaN   NaN
#                     Vijay Varma       5566534.0    5566534.0      65.0  65.0
# Çagan Irmak         Çetin Tekindor  461855363.0  461855363.0       NaN   NaN
# Ömer Faruk Sorak    Cem Yilmaz      196206077.0  196206077.0       NaN   NaN
#
#
#                                     mean
# Director            Star1
# Aamir Khan          Amole Gupte      NaN
# Aaron Sorkin        Eddie Redmayne  77.0
# Abdellatif Kechiche Léa Seydoux     89.0
# Abhishek Chaubey    Shahid Kapoor    NaN
# Abhishek Kapoor     Amit Sadh       40.0
# ...                                  ...
# Zaza Urushadze      Lembit Ulfsak   73.0
# Zoya Akhtar         Hrithik Roshan   NaN
#                     Vijay Varma     65.0
# Çagan Irmak         Çetin Tekindor   NaN
# Ömer Faruk Sorak    Cem Yilmaz       NaN
#
# [898 rows x 15 columns]

# %%
df=pd.read_csv('/content/deliveries.csv')

df[df['batsman'].str.startswith('M')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2809294427.py in <cell line: 0>()
#       1 df=pd.read_csv('/content/deliveries.csv')
#       2
# ----> 3 df[df['batsman'].str.startswith('M')]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
# -> 4092         if com.is_bool_indexer(key):
#    4093             return self._getitem_bool_array(key)
#    4094
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     134                     # Don't raise on e.g. ["A", "B", np.nan], see
#     135                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
# find top 10 batsman ran

df.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False)[:10]

# %%
runs=df.groupby('batsman')['batsman_runs']

six=df[df['batsman_runs']==6].groupby('batsman')['batsman_runs'].value_counts().sort_values(ascending=False)

six.index[0]

# %%
# find the batsman who hits 4's and 6's last 5 over

lastFiveover=df[df['over']>=15]



lastFiveover[((lastFiveover.batsman_runs==4) | (lastFiveover.batsman_runs==6))].groupby('batsman')['batsman'].count().sort_values(ascending=False)

# %%
# find v.koli highest 4's agaist team

dataVk=df[df['batsman']=='V Kohli']

dataVk[dataVk.batsman_runs==4].groupby('bowling_team')['batsman_runs'].value_counts().sort_values(ascending=False).reset_index()

# %%
# find higest sixs vk

vk=df[df.batsman=='V Kohli']

vk[vk.batsman_runs==6].groupby('bowling_team')['batsman_runs'].value_counts().sort_values(ascending=False).reset_index()

# %%
# input a name function will be return the highest score of that's batsman
def HighestRunInOneMatch(name='V Kohli'):
  player=df[df.batsman==name]
  run=player.groupby(['match_id','bowling_team']).agg({'batsman_runs':'sum'}).reset_index()
  return run.sort_values(by='batsman_runs',ascending=False).rename(columns={'bowling_team':'opponent','batsman_runs':'Highest_run'}).head(10)

# %%
batsman=HighestRunInOneMatch('MS Dhoni')

print(batsman)

batsman.plot(kind='bar',x='match_id',y='Highest_run',figsize=(8,6),color='slateblue')
